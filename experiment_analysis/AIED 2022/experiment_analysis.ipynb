# %%
import os
import time
import numpy as np
import pandas as pd
import hickle as hkl

from collections import defaultdict

from sklearn.metrics import roc_auc_score, r2_score, accuracy_score, explained_variance_score, mean_absolute_error, mean_squared_error

import keras
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Masking, Dropout, LSTM, Dense, Concatenate, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping

from IPython.core.display import display, HTML



# Hide GPU from visible devices

#'''
tf.config.set_visible_devices([], 'GPU')
print(f'CUDA GPU AVAILABLE: {tf.test.is_gpu_available(cuda_only=True)}')
'''
THREADS = 8
os.environ['OMP_NUM_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTEROP_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTRAOP_THREADS'] = str(THREADS)
tf.config.threading.set_inter_op_parallelism_threads(THREADS)
tf.config.threading.set_intra_op_parallelism_threads(THREADS)
tf.config.set_soft_device_placement(True)
'''

#'''
display(HTML("<style>.container { width:100% !important; }</style>"))
#'''
# Out:
# WARNING:tensorflow:From <ipython-input-1-b7b55a5d1490>:25: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# CUDA GPU AVAILABLE: False
# <style>.container { width:100% !important; }</style>

# %%
# Wait for process_data to finish

while 'experiment_data__20_steps__60_days.hkl' not in os.listdir('data/processed_data'):
    time.sleep(600)

#time.sleep(3600)

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean((y_pred - y_true) / y_true)

# %%
N_STEPS = 20
N_DAYS = 60
DATA = f'data/processed_data/experiment_data__{N_STEPS}_steps__{N_DAYS}_days.hkl'

# %%
# Store results
results = []

# Load one partition of folds
data = hkl.load(DATA)
action_remnant_input = data['action_remnant_input']
recurrent_remnant_input = data['recurrent_remnant_input']
prior_remnant_input = data['prior_remnant_input']
completion_remnant_target = data['completion_remnant_target']
problems_remnant_target = data['problems_remnant_target']
action_experiment_input = data['action_experiment_input']
recurrent_experiment_input = data['recurrent_experiment_input']
prior_experiment_input = data['prior_experiment_input']
completion_experiment_target = data['completion_experiment_target']
problems_experiment_target = data['problems_experiment_target']
experiment_sequence = data['experiment_sequence']
experiment_assignment_log_id = data['experiment_assignment_log_id']

# Clear session so models don't pile up
keras.backend.clear_session()

# Create model

# Action Model
action_input_layer = Input(shape=action_remnant_input[0].shape, name='action')
action_model = Dropout(rate=0.5)(action_input_layer)
action_model_hook = LSTM(units=64, return_sequences=False, activation='relu', dropout=0.5, recurrent_dropout=0.5)(action_model)
action_model = Dropout(rate=0.5)(action_model_hook)

action_completion_output_layer = Dense(units=1, activation='sigmoid', name='action_completion')(action_model)
action_problems_output_layer = Dense(units=1, activation='linear', name='action_problems')(action_model)

action_model = Model(action_input_layer, [action_completion_output_layer, action_problems_output_layer])
action_model.compile(optimizer='adam', loss={'action_completion': 'binary_crossentropy', 'action_problems': 'mse'})


# Recurrent Model
recurrent_input_layer = Input(shape=recurrent_remnant_input[0].shape, name='recurrent')
recurrent_model = Masking(mask_value=0.0)(recurrent_input_layer)
recurrent_model = Dropout(rate=0.5)(recurrent_model)
recurrent_model_hook = LSTM(units=64, return_sequences=False, dropout=0.5, recurrent_dropout=0.5)(recurrent_model)
recurrent_model = Dropout(rate=0.5)(recurrent_model_hook)

recurrent_completion_output_layer = Dense(units=1, activation='sigmoid', name='recurrent_completion')(recurrent_model)
recurrent_problems_output_layer = Dense(units=1, activation='linear', name='recurrent_problems')(recurrent_model)

recurrent_model = Model(recurrent_input_layer, [recurrent_completion_output_layer, recurrent_problems_output_layer])
recurrent_model.compile(optimizer='adam', loss={'recurrent_completion': 'binary_crossentropy', 'recurrent_problems': 'mse'})


# Prior Model
prior_input_layer = Input(shape=prior_remnant_input[0].shape, name='prior')
prior_model = Dropout(rate=0.5)(prior_input_layer)
prior_model_hook = Dense(units=64, activation='sigmoid')(prior_model)
prior_model = Dropout(rate=0.5)(prior_model_hook)

prior_completion_output_layer = Dense(units=1, activation='sigmoid', name='prior_completion')(prior_model)
prior_problems_output_layer = Dense(units=1, activation='linear', name='prior_problems')(prior_model)

prior_model = Model(prior_input_layer, [prior_completion_output_layer, prior_problems_output_layer])
prior_model.compile(optimizer='adam', loss={'prior_completion': 'binary_crossentropy', 'prior_problems': 'mse'})


# Combined Model
combined_model = Concatenate()([action_model_hook, recurrent_model_hook, prior_model_hook])
combined_model = Dropout(rate=0.5)(combined_model)
combined_completion_output_layer = Dense(units=1, activation='sigmoid', name='combined_completion')(combined_model)
combined_problems_output_layer = Dense(units=1, activation='linear', name='combined_problems')(combined_model)

combined_model = Model([action_input_layer, recurrent_input_layer, prior_input_layer], [combined_completion_output_layer, combined_problems_output_layer])
combined_model.compile(optimizer='adam', loss={'combined_completion': 'binary_crossentropy', 'combined_problems': 'mse'})


# Train Models
es = [EarlyStopping(monitor='val_loss', patience=10, min_delta=0, restore_best_weights=True)]


# Train Partial Models
weights = {'action_completion': np.ones_like(completion_remnant_target) * 16, 'action_problems': completion_remnant_target}
action_model.fit(x={'action': action_remnant_input},
                 y={'action_completion': completion_remnant_target, 'action_problems': problems_remnant_target},
                 epochs=1000,
                 validation_split=0.25,
                 callbacks=es,
                 sample_weight=weights,
                 verbose=1)

completion_experiment_output, problems_experiment_output = action_model.predict({'action': action_experiment_input})
df = pd.DataFrame(zip(np.array(['action'] * experiment_sequence.size), 
                      experiment_sequence.flatten(), 
                      experiment_assignment_log_id.flatten(), 
                      completion_experiment_target.flatten(), 
                      problems_experiment_target.flatten(), 
                      completion_experiment_output.flatten(), 
                      problems_experiment_output.flatten()), 
                  columns = ['model', 
                             'sequence_id', 
                             'assignment_log_id', 
                             'completion_target', 
                             'problems_target', 
                             'completion_prediction', 
                             'problems_prediction'])
results.append(df)


weights = {'recurrent_completion': np.ones_like(completion_remnant_target) * 16, 'recurrent_problems': completion_remnant_target}
recurrent_model.fit(x={'recurrent': recurrent_remnant_input},
                    y={'recurrent_completion': completion_remnant_target, 'recurrent_problems': problems_remnant_target},
                    epochs=1000,
                    validation_split=0.25,
                    callbacks=es,
                    sample_weight=weights,
                    verbose=1)

completion_experiment_output, problems_experiment_output = recurrent_model.predict({'recurrent': recurrent_experiment_input})
df = pd.DataFrame(zip(np.array(['assignment'] * experiment_sequence.size), 
                      experiment_sequence.flatten(), 
                      experiment_assignment_log_id.flatten(), 
                      completion_experiment_target.flatten(), 
                      problems_experiment_target.flatten(), 
                      completion_experiment_output.flatten(), 
                      problems_experiment_output.flatten()), 
                  columns = ['model', 
                             'sequence_id', 
                             'assignment_log_id', 
                             'completion_target', 
                             'problems_target', 
                             'completion_prediction', 
                             'problems_prediction'])
results.append(df)


weights = {'prior_completion': np.ones_like(completion_remnant_target) * 16, 'prior_problems': completion_remnant_target}
prior_model.fit(x={'prior': prior_remnant_input},
                y={'prior_completion': completion_remnant_target, 'prior_problems': problems_remnant_target},
                epochs=1000,
                validation_split=0.25,
                callbacks=es,
                sample_weight=weights,
                verbose=1)

completion_experiment_output, problems_experiment_output = prior_model.predict({'prior': prior_experiment_input})
df = pd.DataFrame(zip(np.array(['student'] * experiment_sequence.size), 
                      experiment_sequence.flatten(), 
                      experiment_assignment_log_id.flatten(), 
                      completion_experiment_target.flatten(), 
                      problems_experiment_target.flatten(), 
                      completion_experiment_output.flatten(), 
                      problems_experiment_output.flatten()), 
                  columns = ['model', 
                             'sequence_id', 
                             'assignment_log_id', 
                             'completion_target', 
                             'problems_target', 
                             'completion_prediction', 
                             'problems_prediction'])
results.append(df)

weights = {'combined_completion': np.ones_like(completion_remnant_target) * 16, 'combined_problems': completion_remnant_target}
combined_model.fit(x={'action': action_remnant_input, 'recurrent': recurrent_remnant_input, 'prior': prior_remnant_input},
                   y={'combined_completion': completion_remnant_target, 'combined_problems': problems_remnant_target},
                   epochs=1000,
                   validation_split=0.25,
                   callbacks=es,
                   sample_weight=weights,
                   verbose=1)

# Store model predictions
completion_experiment_output, problems_experiment_output = combined_model.predict({'action': action_experiment_input, 
                                                                                   'recurrent': recurrent_experiment_input, 
                                                                                   'prior': prior_experiment_input})
df = pd.DataFrame(zip(np.array(['combined'] * experiment_sequence.size), 
                      experiment_sequence.flatten(), 
                      experiment_assignment_log_id.flatten(), 
                      completion_experiment_target.flatten(), 
                      problems_experiment_target.flatten(), 
                      completion_experiment_output.flatten(), 
                      problems_experiment_output.flatten()), 
                  columns = ['model', 
                             'sequence_id', 
                             'assignment_log_id', 
                             'completion_target', 
                             'problems_target', 
                             'completion_prediction', 
                             'problems_prediction'])
results.append(df)

results = pd.concat(results)
experiment_conditions = pd.read_csv('data/experiment_information/experiment_conditions.csv').drop('sequence_id', axis=1)
results = results.merge(experiment_conditions, how='left', on='assignment_log_id')
results.to_csv('experiment_results.csv', index=False)
# Out:
# Epoch 1/1000
# 3578/3578 [==============================] - 215s 60ms/step - loss: 20.9316 - action_completion_loss: 9.0110 - action_problems_loss: 11.9207 - val_loss: 14.9495 - val_action_completion_loss: 9.8909 - val_action_problems_loss: 5.0586
# Epoch 2/1000
# 3578/3578 [==============================] - 216s 60ms/step - loss: 16.1518 - action_completion_loss: 8.8343 - action_problems_loss: 7.3175 - val_loss: 14.8118 - val_action_completion_loss: 9.7281 - val_action_problems_loss: 5.0837
# Epoch 3/1000
# 3578/3578 [==============================] - 210s 59ms/step - loss: 15.9250 - action_completion_loss: 8.7594 - action_problems_loss: 7.1656 - val_loss: 14.6078 - val_action_completion_loss: 9.6139 - val_action_problems_loss: 4.9938
# Epoch 4/1000
# 3578/3578 [==============================] - 212s 59ms/step - loss: 15.7820 - action_completion_loss: 8.7038 - action_problems_loss: 7.0782 - val_loss: 14.5300 - val_action_completion_loss: 9.5068 - val_action_problems_loss: 5.0232
# Epoch 5/1000
# 3578/3578 [==============================] - 212s 59ms/step - loss: 15.7252 - action_completion_loss: 8.6721 - action_problems_loss: 7.0531 - val_loss: 14.5692 - val_action_completion_loss: 9.5592 - val_action_problems_loss: 5.0101
# Epoch 6/1000
# 3578/3578 [==============================] - 209s 58ms/step - loss: 15.6676 - action_completion_loss: 8.6403 - action_problems_loss: 7.0273 - val_loss: 14.4498 - val_action_completion_loss: 9.4720 - val_action_problems_loss: 4.9779
# Epoch 7/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 17.2142 - action_completion_loss: 8.6646 - action_problems_loss: 8.5496 - val_loss: 14.5393 - val_action_completion_loss: 9.5575 - val_action_problems_loss: 4.9818
# Epoch 8/1000
# 3578/3578 [==============================] - 208s 58ms/step - loss: 15.6167 - action_completion_loss: 8.6224 - action_problems_loss: 6.9943 - val_loss: 14.4911 - val_action_completion_loss: 9.5170 - val_action_problems_loss: 4.9741
# Epoch 9/1000
# 3578/3578 [==============================] - 206s 58ms/step - loss: 15.5864 - action_completion_loss: 8.5940 - action_problems_loss: 6.9923 - val_loss: 14.4589 - val_action_completion_loss: 9.4809 - val_action_problems_loss: 4.9780
# Epoch 10/1000
# 3578/3578 [==============================] - 211s 59ms/step - loss: 15.5648 - action_completion_loss: 8.5846 - action_problems_loss: 6.9802 - val_loss: 14.4502 - val_action_completion_loss: 9.4670 - val_action_problems_loss: 4.9833
# Epoch 11/1000
# 3578/3578 [==============================] - 214s 60ms/step - loss: 15.5647 - action_completion_loss: 8.5883 - action_problems_loss: 6.9764 - val_loss: 14.4975 - val_action_completion_loss: 9.5093 - val_action_problems_loss: 4.9881
# Epoch 12/1000
# 3578/3578 [==============================] - 208s 58ms/step - loss: 15.5485 - action_completion_loss: 8.5662 - action_problems_loss: 6.9823 - val_loss: 14.4291 - val_action_completion_loss: 9.4424 - val_action_problems_loss: 4.9867
# Epoch 13/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 15.5200 - action_completion_loss: 8.5505 - action_problems_loss: 6.9695 - val_loss: 14.4320 - val_action_completion_loss: 9.4391 - val_action_problems_loss: 4.9929
# Epoch 14/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 15.5079 - action_completion_loss: 8.5419 - action_problems_loss: 6.9661 - val_loss: 14.4614 - val_action_completion_loss: 9.4686 - val_action_problems_loss: 4.9929
# Epoch 15/1000
# 3578/3578 [==============================] - 209s 59ms/step - loss: 15.5028 - action_completion_loss: 8.5430 - action_problems_loss: 6.9598 - val_loss: 14.4149 - val_action_completion_loss: 9.4303 - val_action_problems_loss: 4.9846
# Epoch 16/1000
# 3578/3578 [==============================] - 206s 58ms/step - loss: 15.4886 - action_completion_loss: 8.5274 - action_problems_loss: 6.9611 - val_loss: 14.5603 - val_action_completion_loss: 9.5439 - val_action_problems_loss: 5.0164
# Epoch 17/1000
# 3578/3578 [==============================] - 208s 58ms/step - loss: 15.5019 - action_completion_loss: 8.5389 - action_problems_loss: 6.9630 - val_loss: 14.4732 - val_action_completion_loss: 9.4843 - val_action_problems_loss: 4.9888
# Epoch 18/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 15.4810 - action_completion_loss: 8.5182 - action_problems_loss: 6.9629 - val_loss: 14.4135 - val_action_completion_loss: 9.4193 - val_action_problems_loss: 4.9942
# Epoch 19/1000
# 3578/3578 [==============================] - 208s 58ms/step - loss: 15.4716 - action_completion_loss: 8.5082 - action_problems_loss: 6.9634 - val_loss: 14.4587 - val_action_completion_loss: 9.4599 - val_action_problems_loss: 4.9988
# Epoch 20/1000
# 3578/3578 [==============================] - 209s 58ms/step - loss: 15.4749 - action_completion_loss: 8.5080 - action_problems_loss: 6.9670 - val_loss: 14.4689 - val_action_completion_loss: 9.4670 - val_action_problems_loss: 5.0019
# Epoch 21/1000
# 3578/3578 [==============================] - 209s 58ms/step - loss: 15.4599 - action_completion_loss: 8.4977 - action_problems_loss: 6.9621 - val_loss: 14.4820 - val_action_completion_loss: 9.4733 - val_action_problems_loss: 5.0086
# Epoch 22/1000
# 3578/3578 [==============================] - 209s 59ms/step - loss: 15.4651 - action_completion_loss: 8.5042 - action_problems_loss: 6.9609 - val_loss: 14.4332 - val_action_completion_loss: 9.4361 - val_action_problems_loss: 4.9972
# Epoch 23/1000
# 3578/3578 [==============================] - 208s 58ms/step - loss: 15.4504 - action_completion_loss: 8.4893 - action_problems_loss: 6.9611 - val_loss: 14.5077 - val_action_completion_loss: 9.4960 - val_action_problems_loss: 5.0117
# Epoch 24/1000
# 3578/3578 [==============================] - 211s 59ms/step - loss: 15.4412 - action_completion_loss: 8.4887 - action_problems_loss: 6.9524 - val_loss: 14.4580 - val_action_completion_loss: 9.4540 - val_action_problems_loss: 5.0040
# Epoch 25/1000
# 3578/3578 [==============================] - 209s 58ms/step - loss: 15.4528 - action_completion_loss: 8.4927 - action_problems_loss: 6.9601 - val_loss: 14.4175 - val_action_completion_loss: 9.4172 - val_action_problems_loss: 5.0002
# Epoch 26/1000
# 3578/3578 [==============================] - 210s 59ms/step - loss: 15.4502 - action_completion_loss: 8.4916 - action_problems_loss: 6.9586 - val_loss: 14.4839 - val_action_completion_loss: 9.4734 - val_action_problems_loss: 5.0104
# Epoch 27/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 15.4429 - action_completion_loss: 8.4865 - action_problems_loss: 6.9563 - val_loss: 14.4293 - val_action_completion_loss: 9.4332 - val_action_problems_loss: 4.9961
# Epoch 28/1000
# 3578/3578 [==============================] - 207s 58ms/step - loss: 15.4308 - action_completion_loss: 8.4752 - action_problems_loss: 6.9556 - val_loss: 14.4285 - val_action_completion_loss: 9.4269 - val_action_problems_loss: 5.0016
# Epoch 1/1000
# 3578/3578 [==============================] - 109s 30ms/step - loss: 15.7476 - recurrent_completion_loss: 8.0839 - recurrent_problems_loss: 7.6638 - val_loss: 13.6079 - val_recurrent_completion_loss: 8.7044 - val_recurrent_problems_loss: 4.9035
# Epoch 2/1000
# 3578/3578 [==============================] - 106s 30ms/step - loss: 15.0950 - recurrent_completion_loss: 7.9038 - recurrent_problems_loss: 7.1911 - val_loss: 13.4976 - val_recurrent_completion_loss: 8.5984 - val_recurrent_problems_loss: 4.8992
# Epoch 3/1000
# 3578/3578 [==============================] - 106s 30ms/step - loss: 14.9328 - recurrent_completion_loss: 7.8480 - recurrent_problems_loss: 7.0847 - val_loss: 13.5065 - val_recurrent_completion_loss: 8.6074 - val_recurrent_problems_loss: 4.8992
# Epoch 4/1000
# 3578/3578 [==============================] - 106s 30ms/step - loss: 14.8405 - recurrent_completion_loss: 7.8363 - recurrent_problems_loss: 7.0041 - val_loss: 13.5340 - val_recurrent_completion_loss: 8.6311 - val_recurrent_problems_loss: 4.9030
# Epoch 5/1000
# 3578/3578 [==============================] - 106s 29ms/step - loss: 14.7538 - recurrent_completion_loss: 7.8103 - recurrent_problems_loss: 6.9435 - val_loss: 13.4811 - val_recurrent_completion_loss: 8.5926 - val_recurrent_problems_loss: 4.8885
# Epoch 6/1000
# 3578/3578 [==============================] - 109s 30ms/step - loss: 14.7073 - recurrent_completion_loss: 7.7981 - recurrent_problems_loss: 6.9092 - val_loss: 13.4820 - val_recurrent_completion_loss: 8.5864 - val_recurrent_problems_loss: 4.8956
# Epoch 7/1000
# 3578/3578 [==============================] - 107s 30ms/step - loss: 14.6575 - recurrent_completion_loss: 7.7749 - recurrent_problems_loss: 6.8826 - val_loss: 13.4556 - val_recurrent_completion_loss: 8.5768 - val_recurrent_problems_loss: 4.8787
# Epoch 8/1000
# 3578/3578 [==============================] - 107s 30ms/step - loss: 14.6193 - recurrent_completion_loss: 7.7664 - recurrent_problems_loss: 6.8529 - val_loss: 13.5367 - val_recurrent_completion_loss: 8.6205 - val_recurrent_problems_loss: 4.9162
# Epoch 9/1000
# 3578/3578 [==============================] - 105s 29ms/step - loss: 14.5835 - recurrent_completion_loss: 7.7437 - recurrent_problems_loss: 6.8399 - val_loss: 13.5483 - val_recurrent_completion_loss: 8.6467 - val_recurrent_problems_loss: 4.9016
# Epoch 10/1000
# 3578/3578 [==============================] - 105s 29ms/step - loss: 14.5560 - recurrent_completion_loss: 7.7315 - recurrent_problems_loss: 6.8246 - val_loss: 13.4687 - val_recurrent_completion_loss: 8.5828 - val_recurrent_problems_loss: 4.8860
# Epoch 11/1000
# 3578/3578 [==============================] - 107s 30ms/step - loss: 14.5599 - recurrent_completion_loss: 7.7490 - recurrent_problems_loss: 6.8109 - val_loss: 13.4969 - val_recurrent_completion_loss: 8.6031 - val_recurrent_problems_loss: 4.8938
# Epoch 12/1000
# 3578/3578 [==============================] - 108s 30ms/step - loss: 14.5331 - recurrent_completion_loss: 7.7182 - recurrent_problems_loss: 6.8150 - val_loss: 13.5256 - val_recurrent_completion_loss: 8.6247 - val_recurrent_problems_loss: 4.9009
# Epoch 13/1000
# 3578/3578 [==============================] - 106s 29ms/step - loss: 14.5162 - recurrent_completion_loss: 7.7182 - recurrent_problems_loss: 6.7980 - val_loss: 13.4783 - val_recurrent_completion_loss: 8.5848 - val_recurrent_problems_loss: 4.8934
# Epoch 14/1000
# 3578/3578 [==============================] - 106s 30ms/step - loss: 14.5029 - recurrent_completion_loss: 7.7066 - recurrent_problems_loss: 6.7963 - val_loss: 13.4697 - val_recurrent_completion_loss: 8.5808 - val_recurrent_problems_loss: 4.8889
# Epoch 15/1000
# 3578/3578 [==============================] - 107s 30ms/step - loss: 14.5047 - recurrent_completion_loss: 7.7035 - recurrent_problems_loss: 6.8012 - val_loss: 13.5251 - val_recurrent_completion_loss: 8.6352 - val_recurrent_problems_loss: 4.8899
# Epoch 16/1000
# 3578/3578 [==============================] - 108s 30ms/step - loss: 14.4824 - recurrent_completion_loss: 7.7071 - recurrent_problems_loss: 6.7753 - val_loss: 13.5105 - val_recurrent_completion_loss: 8.6211 - val_recurrent_problems_loss: 4.8894
# Epoch 17/1000
# 3578/3578 [==============================] - 112s 31ms/step - loss: 14.4809 - recurrent_completion_loss: 7.6938 - recurrent_problems_loss: 6.7871 - val_loss: 13.5073 - val_recurrent_completion_loss: 8.6027 - val_recurrent_problems_loss: 4.9046
# Epoch 1/1000
# 3578/3578 [==============================] - 7s 2ms/step - loss: 16.1394 - prior_completion_loss: 8.4628 - prior_problems_loss: 7.6765 - val_loss: 13.7188 - val_prior_completion_loss: 8.8312 - val_prior_problems_loss: 4.8876
# Epoch 2/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.3902 - prior_completion_loss: 8.2744 - prior_problems_loss: 7.1157 - val_loss: 13.7308 - val_prior_completion_loss: 8.8403 - val_prior_problems_loss: 4.8906
# Epoch 3/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.2851 - prior_completion_loss: 8.2205 - prior_problems_loss: 7.0647 - val_loss: 13.6878 - val_prior_completion_loss: 8.8012 - val_prior_problems_loss: 4.8866
# Epoch 4/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.2327 - prior_completion_loss: 8.1984 - prior_problems_loss: 7.0343 - val_loss: 13.6934 - val_prior_completion_loss: 8.8169 - val_prior_problems_loss: 4.8765
# Epoch 5/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.2007 - prior_completion_loss: 8.2019 - prior_problems_loss: 6.9989 - val_loss: 13.7115 - val_prior_completion_loss: 8.8209 - val_prior_problems_loss: 4.8907
# Epoch 6/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.1700 - prior_completion_loss: 8.1761 - prior_problems_loss: 6.9939 - val_loss: 13.6931 - val_prior_completion_loss: 8.8158 - val_prior_problems_loss: 4.8773
# Epoch 7/1000
# 3578/3578 [==============================] - 5s 1ms/step - loss: 15.1387 - prior_completion_loss: 8.1930 - prior_problems_loss: 6.9457 - val_loss: 13.6926 - val_prior_completion_loss: 8.8102 - val_prior_problems_loss: 4.8825
# Epoch 8/1000
# 3578/3578 [==============================] - 5s 2ms/step - loss: 15.0913 - prior_completion_loss: 8.1650 - prior_problems_loss: 6.9263 - val_loss: 13.6231 - val_prior_completion_loss: 8.7517 - val_prior_problems_loss: 4.8714
# Epoch 9/1000
# 3578/3578 [==============================] - 7s 2ms/step - loss: 15.1003 - prior_completion_loss: 8.1657 - prior_problems_loss: 6.9346 - val_loss: 13.6468 - val_prior_completion_loss: 8.7754 - val_prior_problems_loss: 4.8714
# Epoch 10/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.0528 - prior_completion_loss: 8.1559 - prior_problems_loss: 6.8969 - val_loss: 13.6716 - val_prior_completion_loss: 8.8011 - val_prior_problems_loss: 4.8705
# Epoch 11/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.0378 - prior_completion_loss: 8.1522 - prior_problems_loss: 6.8856 - val_loss: 13.6705 - val_prior_completion_loss: 8.7973 - val_prior_problems_loss: 4.8732
# Epoch 12/1000
# 3578/3578 [==============================] - 5s 2ms/step - loss: 15.0199 - prior_completion_loss: 8.1425 - prior_problems_loss: 6.8774 - val_loss: 13.6645 - val_prior_completion_loss: 8.7935 - val_prior_problems_loss: 4.8710
# Epoch 13/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.0254 - prior_completion_loss: 8.1392 - prior_problems_loss: 6.8862 - val_loss: 13.6387 - val_prior_completion_loss: 8.7606 - val_prior_problems_loss: 4.8781
# Epoch 14/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 15.0227 - prior_completion_loss: 8.1523 - prior_problems_loss: 6.8705 - val_loss: 13.6812 - val_prior_completion_loss: 8.8052 - val_prior_problems_loss: 4.8760
# Epoch 15/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 14.9811 - prior_completion_loss: 8.1263 - prior_problems_loss: 6.8549 - val_loss: 13.6511 - val_prior_completion_loss: 8.7808 - val_prior_problems_loss: 4.8703
# Epoch 16/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 14.9912 - prior_completion_loss: 8.1406 - prior_problems_loss: 6.8506 - val_loss: 13.6565 - val_prior_completion_loss: 8.7809 - val_prior_problems_loss: 4.8757
# Epoch 17/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 14.9931 - prior_completion_loss: 8.1320 - prior_problems_loss: 6.8611 - val_loss: 13.6863 - val_prior_completion_loss: 8.8099 - val_prior_problems_loss: 4.8764
# Epoch 18/1000
# 3578/3578 [==============================] - 6s 2ms/step - loss: 14.9677 - prior_completion_loss: 8.1248 - prior_problems_loss: 6.8429 - val_loss: 13.6396 - val_prior_completion_loss: 8.7721 - val_prior_problems_loss: 4.8676
# Epoch 1/1000
# 3578/3578 [==============================] - 234s 65ms/step - loss: 14.9462 - combined_completion_loss: 7.7943 - combined_problems_loss: 7.1518 - val_loss: 13.3465 - val_combined_completion_loss: 8.4861 - val_combined_problems_loss: 4.8604
# Epoch 2/1000
# 3578/3578 [==============================] - 232s 65ms/step - loss: 14.5390 - combined_completion_loss: 7.6368 - combined_problems_loss: 6.9022 - val_loss: 13.3552 - val_combined_completion_loss: 8.5016 - val_combined_problems_loss: 4.8536
# Epoch 3/1000
# 3578/3578 [==============================] - 247s 69ms/step - loss: 14.4777 - combined_completion_loss: 7.5989 - combined_problems_loss: 6.8788 - val_loss: 13.3288 - val_combined_completion_loss: 8.4843 - val_combined_problems_loss: 4.8445
# Epoch 4/1000
# 3578/3578 [==============================] - 248s 69ms/step - loss: 14.4340 - combined_completion_loss: 7.6018 - combined_problems_loss: 6.8322 - val_loss: 13.3158 - val_combined_completion_loss: 8.4626 - val_combined_problems_loss: 4.8532
# Epoch 5/1000
# 3578/3578 [==============================] - 248s 69ms/step - loss: 14.4207 - combined_completion_loss: 7.6001 - combined_problems_loss: 6.8206 - val_loss: 13.2854 - val_combined_completion_loss: 8.4403 - val_combined_problems_loss: 4.8451
# Epoch 6/1000
# 3578/3578 [==============================] - 241s 67ms/step - loss: 14.3794 - combined_completion_loss: 7.5711 - combined_problems_loss: 6.8084 - val_loss: 13.3307 - val_combined_completion_loss: 8.4744 - val_combined_problems_loss: 4.8563
# Epoch 7/1000
# 3578/3578 [==============================] - 244s 68ms/step - loss: 14.3547 - combined_completion_loss: 7.5777 - combined_problems_loss: 6.7769 - val_loss: 13.3010 - val_combined_completion_loss: 8.4500 - val_combined_problems_loss: 4.8511
# Epoch 8/1000
# 3578/3578 [==============================] - 248s 69ms/step - loss: 14.3328 - combined_completion_loss: 7.5728 - combined_problems_loss: 6.7600 - val_loss: 13.3619 - val_combined_completion_loss: 8.4788 - val_combined_problems_loss: 4.8831
# Epoch 9/1000
# 3578/3578 [==============================] - 249s 69ms/step - loss: 14.3297 - combined_completion_loss: 7.5793 - combined_problems_loss: 6.7504 - val_loss: 13.3651 - val_combined_completion_loss: 8.4952 - val_combined_problems_loss: 4.8699
# Epoch 10/1000
# 3578/3578 [==============================] - 249s 70ms/step - loss: 14.3000 - combined_completion_loss: 7.5654 - combined_problems_loss: 6.7346 - val_loss: 13.3834 - val_combined_completion_loss: 8.4824 - val_combined_problems_loss: 4.9010
# Epoch 11/1000
# 3578/3578 [==============================] - 250s 70ms/step - loss: 14.3203 - combined_completion_loss: 7.5552 - combined_problems_loss: 6.7651 - val_loss: 13.3586 - val_combined_completion_loss: 8.4959 - val_combined_problems_loss: 4.8628
# Epoch 12/1000
# 3578/3578 [==============================] - 239s 67ms/step - loss: 14.2964 - combined_completion_loss: 7.5532 - combined_problems_loss: 6.7432 - val_loss: 13.3330 - val_combined_completion_loss: 8.4580 - val_combined_problems_loss: 4.8749
# Epoch 13/1000
# 3578/3578 [==============================] - 249s 70ms/step - loss: 14.2682 - combined_completion_loss: 7.5540 - combined_problems_loss: 6.7142 - val_loss: 13.3202 - val_combined_completion_loss: 8.4525 - val_combined_problems_loss: 4.8677
# Epoch 14/1000
# 3578/3578 [==============================] - 258s 72ms/step - loss: 14.2609 - combined_completion_loss: 7.5525 - combined_problems_loss: 6.7084 - val_loss: 13.3319 - val_combined_completion_loss: 8.4706 - val_combined_problems_loss: 4.8612
# Epoch 15/1000
# 3578/3578 [==============================] - 270s 76ms/step - loss: 14.2351 - combined_completion_loss: 7.5446 - combined_problems_loss: 6.6905 - val_loss: 13.3877 - val_combined_completion_loss: 8.5177 - val_combined_problems_loss: 4.8700

# %%
# Load the data

results = pd.read_csv('experiment_results.csv')

# %%
# Evaluate the results

metrics = []

# Calculate the metrics for each sequence

for keys, df in results.groupby(['model', 'sequence_id']):
    
    model, sequence = keys
    
    completion_target = df['completion_target']
    
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)
    
    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([model, 
                    sequence, 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])


# Calculate the metrics for everything combined

for model, df in results.groupby('model'):

    completion_target = df['completion_target']
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)

    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([model,
                    'all_data', 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])

metrics = pd.DataFrame(metrics, 
                       columns=['model',
                                'group', 
                                'sample_size', 
                                'completion_auc', 
                                'completion_acc', 
                                'completion_r2', 
                                'completion_ev', 
                                'completion_mse', 
                                'problems_mae', 
                                'problems_mape', 
                                'problems_r2', 
                                'problems_ev', 
                                'problems_mse'])

metrics.to_csv('experiment_metrics.csv', index=False)

# %%
metrics.iloc[-10:]
# Out:
#           model     group  sample_size  completion_auc  completion_acc  \
# 350     student   PSAXP7W           64        0.666667        0.921875
# 351     student   PSAXTEE           47        0.764815        0.659574
# 352     student   PSAYCFH         1903        0.771336        0.627956
# 353     student   PSAZ2G4          185        0.826179        0.572973
# 354     student   PSAZ5HX          800        0.703821        0.560000
# 355     student   PSAZGQM          288        0.736304        0.875000
# 356      action  all_data       101780        0.652257        0.694911
# 357  assignment  all_data       101780        0.727226        0.724946
# 358    combined  all_data       101780        0.758698        0.744380
# 359     student  all_data       101780        0.754174        0.730212
#
#      completion_r2  completion_ev  completion_mse  problems_mae  \
# 350       0.068034       0.112896        0.079181      3.472874
# 351       0.047152       0.156737        0.232928      2.486858
# 352       0.100232       0.181707        0.223600      5.694859
# 353       0.051630       0.209007        0.236254      5.961732
# 354      -0.019553       0.115909        0.254530     11.570453
# 355      -0.006688       0.066830        0.102132      3.625835
# 356       0.051181       0.056781        0.201958      3.698238
# 357       0.125130       0.130488        0.186217      3.707255
# 358       0.175750       0.183537        0.175443      3.760128
# 359       0.154286       0.168547        0.180012      3.757767
#
#      problems_mape  problems_r2  problems_ev  problems_mse
# 350      -0.327498    -0.755138     0.027607     26.527422
# 351       0.070241    -0.073571     0.019975      8.918442
# 352      -0.497558    -2.761556     0.024656     43.784396
# 353      -0.530502    -3.945087     0.060542     43.878124
# 354      -0.047744    -0.331979     0.003526    391.401488
# 355      -0.328367    -0.896371     0.012042     26.458080
# 356      -0.207515    -0.415249     0.009925     31.608818
# 357      -0.211424    -0.407008     0.019357     31.424764
# 358      -0.235159    -0.421152     0.038306     31.740665
# 359      -0.230035    -0.429836     0.028052     31.934620

# %%
results.iloc[-10:]
# Out:
#            model sequence_id  assignment_log_id  completion_target  \
# 407110  combined     PSAUTWU           18397915                  0
# 407111  combined     PSA2KKZ           18395857                  1
# 407112  combined     PSAUTWT           18414481                  1
# 407113  combined     PSAUUKY           18414970                  0
# 407114  combined     PSAUUKY           18415013                  0
# 407115  combined     PSAUUKY           18414291                  1
# 407116  combined     PSAUUKY           18418421                  0
# 407117  combined     PSAUTWT           18398639                  0
# 407118  combined     PSAUTWT           18398571                  0
# 407119  combined     PSAUTWT           18398567                  0
#
#         problems_target  completion_prediction  problems_prediction  \
# 407110               10               0.788966             4.171197
# 407111               12               0.800838             5.788163
# 407112                5               0.857710             4.217018
# 407113                7               0.787538             4.484480
# 407114                7               0.295553             5.164132
# 407115                9               0.874131             3.898782
# 407116                7               0.791765             4.418406
# 407117                3               0.701583             3.770533
# 407118                2               0.527321             4.167850
# 407119                4               0.697395             3.731581
#
#           user_id  in_control  in_treatment
# 407110  1129695.0         0.0           1.0
# 407111  1129849.0         0.0           1.0
# 407112  1130045.0         1.0           0.0
# 407113  1130054.0         1.0           0.0
# 407114  1130059.0         1.0           0.0
# 407115  1130061.0         1.0           0.0
# 407116  1130196.0         1.0           0.0
# 407117  1130203.0         0.0           1.0
# 407118  1130204.0         0.0           0.0
# 407119  1130219.0         0.0           1.0
