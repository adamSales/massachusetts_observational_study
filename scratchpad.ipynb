# %%
import pandas as pd

# %%
df = pd.read_csv('remnant_model/input_data/matches.csv', dtype=str)

# %%
df[df['trt'] == '1']
# Out:
#     school_code trt fullmatch pairmatch
# 8      00050405   1      1.37      1.37
# 20     00170305   1       1.9       1.9
# 28     00250315   1      1.17      1.17
# 69     00350560   1      1.36      1.36
# 119    00770100   1       1.1       1.1
# 120    00770505   1       1.2       1.2
# 124    00860305   1       1.3       1.3
# 130    00930018   1       1.4       1.4
# 144    01000302   1       1.5       1.5
# 175    01370040   1       1.6       1.6
# 179    01390305   1       1.7       1.7
# 198    01530320   1       1.8       1.8
# 210    01620020   1      1.10      1.10
# 233    01770305   1      1.11      1.11
# 239    01850310   1      1.12      1.12
# 240    01870020   1      1.13      1.13
# 244    01980305   1      1.14      1.14
# 245    01980310   1      1.15      1.15
# 249    02010415   1      1.16      1.16
# 292    02510305   1      1.18      1.18
# 333    02920305   1      1.19      1.19
# 347    03070305   1      1.20      1.20
# ...

# %%
# a lot have elementary grades with middle school, one has only 6th, one has only 8th, most have 67, 78, or 678
