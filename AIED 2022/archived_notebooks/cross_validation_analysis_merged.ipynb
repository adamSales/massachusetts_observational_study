# %%
import os
import numpy as np
import pandas as pd
import hickle as hkl

from collections import defaultdict

from sklearn.metrics import roc_auc_score, r2_score, accuracy_score, explained_variance_score, mean_absolute_error, mean_squared_error

import keras
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Masking, Dropout, LSTM, Dense, Concatenate
from tensorflow.keras.callbacks import EarlyStopping

from IPython.core.display import display, HTML



# Hide GPU from visible devices

#'''
tf.config.set_visible_devices([], 'GPU')
print(f'CUDA GPU AVAILABLE: {tf.test.is_gpu_available(cuda_only=True)}')
'''
THREADS = 8
os.environ['OMP_NUM_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTEROP_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTRAOP_THREADS'] = str(THREADS)
tf.config.threading.set_inter_op_parallelism_threads(THREADS)
tf.config.threading.set_intra_op_parallelism_threads(THREADS)
tf.config.set_soft_device_placement(True)
'''

#'''
display(HTML("<style>.container { width:100% !important; }</style>"))
#'''
# Out:
# WARNING:tensorflow:From <ipython-input-1-4af43bb73841>:24: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# CUDA GPU AVAILABLE: True
# <style>.container { width:100% !important; }</style>

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean((y_pred - y_true) / y_true)

# %%
N_SPLITS = 5
N_STEPS = 20
N_DAYS = 60
DATA_DIR = f'data/processed_data/sb_cv_data__{N_SPLITS}_class_id_folds__{N_STEPS}_steps__{N_DAYS}_days'

# %%
results = []

for i in range(N_SPLITS):

    # Load one partition of folds
    data = hkl.load(f'{DATA_DIR}/fold_{i}.hkl')
    action_training_input = data['action_training_input']
    recurrent_training_input = data['recurrent_training_input']
    prior_training_input = data['prior_training_input']
    completion_training_target = data['completion_training_target']
    problems_training_target = data['problems_training_target']
    training_target_sequence = data['training_target_sequence']
    action_testing_input = data['action_testing_input']
    recurrent_testing_input = data['recurrent_testing_input']
    prior_testing_input = data['prior_testing_input']
    completion_testing_target = data['completion_testing_target']
    problems_testing_target = data['problems_testing_target']
    testing_target_sequence = data['testing_target_sequence']
    
    # Clear session so models don't pile up
    keras.backend.clear_session()

    # Create model
    
    # Action Model
    action_input_layer = Input(shape=action_training_input[0].shape, name='action')
    action_model = Dropout(rate=0.5)(action_input_layer)
    action_model = LSTM(units=64, return_sequences=False, activation='relu', dropout=0.5, recurrent_dropout=0.5)(action_model)
    
    # Recurrent Input
    recurrent_input_layer = Input(shape=recurrent_training_input[0].shape, name='recurrent')
    recurrent_model = Masking(mask_value=0.0)(recurrent_input_layer)
    recurrent_model = Dropout(rate=0.5)(recurrent_model)
    recurrent_model = LSTM(units=64, return_sequences=False, dropout=0.5, recurrent_dropout=0.5)(recurrent_model)
    
    # Prior Input
    prior_input_layer = Input(shape=prior_training_input[0].shape, name='prior')
    prior_model = Dropout(rate=0.5)(prior_input_layer)
    prior_model = Dense(units=64, activation='sigmoid')(prior_model)
    
    # Combined Model
    model = Concatenate()([action_model, recurrent_model, prior_model])
    model = Dropout(rate=0.5)(model)
    
    # Combined Output
    completion_output_layer = Dense(units=1, activation='sigmoid', name='completion')(model)
    problems_output_layer = Dense(units=1, activation='linear', name='problems')(model)
    
    combined_model = Model([action_input_layer, recurrent_input_layer, prior_input_layer], [completion_output_layer, problems_output_layer])
    combined_model.compile(optimizer='adam', loss={'completion': 'binary_crossentropy', 'problems': 'mse'})

    # Train model
    es = [EarlyStopping(monitor='val_loss', patience=10, min_delta=0, restore_best_weights=True)]
    weights = {'completion': np.ones_like(completion_training_target) * 16, 'problems': completion_training_target}
    combined_model.fit(x={'action': action_training_input, 'recurrent': recurrent_training_input, 'prior': prior_training_input},
                       y={'completion': completion_training_target, 'problems': problems_training_target},
                       epochs=1000,
                       validation_split=0.25,
                       callbacks=es,
                       sample_weight=weights,
                       verbose=1)
    
    # Store model predictions
    completion_testing_output, problems_testing_output = combined_model.predict({'action': action_testing_input, 
                                                                                 'recurrent': recurrent_testing_input, 
                                                                                 'prior': prior_testing_input})
    df = pd.DataFrame(zip(np.ones_like(testing_target_sequence).flatten() * i, 
                          testing_target_sequence.flatten(), 
                          completion_testing_target.flatten(), 
                          problems_testing_target.flatten(), 
                          completion_testing_output.flatten(), 
                          problems_testing_output.flatten()), 
                      columns = ['fold', 
                                 'target_sequence', 
                                 'completion_target', 
                                 'problems_target', 
                                 'completion_prediction', 
                                 'problems_prediction'])
    results.append(df)
    

pd.concat(results).to_csv('merged_cross_validation_results.csv', index=False)
# Out:
# Epoch 1/1000
# 162/162 [==============================] - 29s 131ms/step - loss: 38.4142 - completion_loss: 9.1016 - problems_loss: 29.3126 - val_loss: 16.4898 - val_completion_loss: 9.1466 - val_problems_loss: 7.3433
# Epoch 2/1000
# 162/162 [==============================] - 20s 126ms/step - loss: 33.7866 - completion_loss: 8.3722 - problems_loss: 25.4144 - val_loss: 16.2273 - val_completion_loss: 9.1357 - val_problems_loss: 7.0916
# Epoch 3/1000
# 162/162 [==============================] - 23s 145ms/step - loss: 32.5190 - completion_loss: 8.1544 - problems_loss: 24.3646 - val_loss: 16.1147 - val_completion_loss: 8.9706 - val_problems_loss: 7.1441
# Epoch 4/1000
# 162/162 [==============================] - 19s 117ms/step - loss: 31.8787 - completion_loss: 7.9922 - problems_loss: 23.8865 - val_loss: 16.4933 - val_completion_loss: 9.2567 - val_problems_loss: 7.2366
# Epoch 5/1000
# 162/162 [==============================] - 19s 120ms/step - loss: 31.3266 - completion_loss: 7.8699 - problems_loss: 23.4566 - val_loss: 16.9053 - val_completion_loss: 9.4420 - val_problems_loss: 7.4633
# Epoch 6/1000
# 162/162 [==============================] - 19s 115ms/step - loss: 31.3520 - completion_loss: 7.8807 - problems_loss: 23.4713 - val_loss: 16.8244 - val_completion_loss: 9.3995 - val_problems_loss: 7.4248
# Epoch 7/1000
# 162/162 [==============================] - 18s 112ms/step - loss: 31.0725 - completion_loss: 7.8220 - problems_loss: 23.2505 - val_loss: 16.7888 - val_completion_loss: 9.2387 - val_problems_loss: 7.5501
# Epoch 8/1000
# 162/162 [==============================] - 20s 123ms/step - loss: 3053.0144 - completion_loss: 13.8953 - problems_loss: 3039.1204 - val_loss: 16.6793 - val_completion_loss: 9.1732 - val_problems_loss: 7.5061
# Epoch 9/1000
# 162/162 [==============================] - 19s 116ms/step - loss: 31.1078 - completion_loss: 7.7611 - problems_loss: 23.3467 - val_loss: 16.6308 - val_completion_loss: 9.1429 - val_problems_loss: 7.4878
# Epoch 10/1000
# 162/162 [==============================] - 19s 115ms/step - loss: 30.7551 - completion_loss: 7.6924 - problems_loss: 23.0627 - val_loss: 16.6575 - val_completion_loss: 9.1058 - val_problems_loss: 7.5517
# Epoch 11/1000
# 162/162 [==============================] - 20s 125ms/step - loss: 30.7745 - completion_loss: 7.7422 - problems_loss: 23.0323 - val_loss: 16.8255 - val_completion_loss: 9.2035 - val_problems_loss: 7.6220
# Epoch 12/1000
# 162/162 [==============================] - 22s 136ms/step - loss: 29.9557 - completion_loss: 7.5996 - problems_loss: 22.3561 - val_loss: 16.8867 - val_completion_loss: 9.1492 - val_problems_loss: 7.7376
# Epoch 13/1000
# 162/162 [==============================] - 22s 134ms/step - loss: 29.5483 - completion_loss: 7.5991 - problems_loss: 21.9492 - val_loss: 17.2422 - val_completion_loss: 9.4828 - val_problems_loss: 7.7594
# Epoch 1/1000
# 162/162 [==============================] - 28s 121ms/step - loss: 69.4206 - completion_loss: 9.0262 - problems_loss: 60.3944 - val_loss: 17.4870 - val_completion_loss: 9.5277 - val_problems_loss: 7.9593
# Epoch 2/1000
# 162/162 [==============================] - 21s 129ms/step - loss: 35.3919 - completion_loss: 8.6044 - problems_loss: 26.7875 - val_loss: 16.8908 - val_completion_loss: 9.0384 - val_problems_loss: 7.8524
# Epoch 3/1000
# 162/162 [==============================] - 21s 132ms/step - loss: 34.2068 - completion_loss: 8.3924 - problems_loss: 25.8143 - val_loss: 16.9649 - val_completion_loss: 9.1162 - val_problems_loss: 7.8487
# Epoch 4/1000
# 162/162 [==============================] - 22s 137ms/step - loss: 33.2802 - completion_loss: 8.2272 - problems_loss: 25.0530 - val_loss: 17.2257 - val_completion_loss: 9.2329 - val_problems_loss: 7.9928
# Epoch 5/1000
# 162/162 [==============================] - 20s 121ms/step - loss: 33.3955 - completion_loss: 8.2364 - problems_loss: 25.1591 - val_loss: 17.1950 - val_completion_loss: 9.3191 - val_problems_loss: 7.8759
# Epoch 6/1000
# 162/162 [==============================] - 21s 130ms/step - loss: 32.3544 - completion_loss: 8.0777 - problems_loss: 24.2767 - val_loss: 17.7038 - val_completion_loss: 9.5527 - val_problems_loss: 8.1511
# Epoch 7/1000
# 162/162 [==============================] - 20s 125ms/step - loss: 32.2625 - completion_loss: 8.0805 - problems_loss: 24.1820 - val_loss: 17.5684 - val_completion_loss: 9.4838 - val_problems_loss: 8.0846
# Epoch 8/1000
# 162/162 [==============================] - 19s 116ms/step - loss: 32.0569 - completion_loss: 8.0288 - problems_loss: 24.0281 - val_loss: 18.2395 - val_completion_loss: 9.6572 - val_problems_loss: 8.5823
# Epoch 9/1000
# 162/162 [==============================] - 16s 102ms/step - loss: 31.3859 - completion_loss: 8.0227 - problems_loss: 23.3632 - val_loss: 17.9325 - val_completion_loss: 9.4029 - val_problems_loss: 8.5297
# Epoch 10/1000
# 162/162 [==============================] - 18s 111ms/step - loss: 31.2078 - completion_loss: 8.0538 - problems_loss: 23.1540 - val_loss: 17.9069 - val_completion_loss: 9.6017 - val_problems_loss: 8.3051
# Epoch 11/1000
# 162/162 [==============================] - 17s 102ms/step - loss: 30.8865 - completion_loss: 7.9523 - problems_loss: 22.9342 - val_loss: 18.4757 - val_completion_loss: 9.7072 - val_problems_loss: 8.7685
# Epoch 12/1000
# 162/162 [==============================] - 14s 86ms/step - loss: 30.9327 - completion_loss: 8.0035 - problems_loss: 22.9292 - val_loss: 18.4610 - val_completion_loss: 9.6716 - val_problems_loss: 8.7894
# Epoch 1/1000
# 162/162 [==============================] - 26s 112ms/step - loss: 21.7704 - completion_loss: 9.3900 - problems_loss: 12.3804 - val_loss: 16.8156 - val_completion_loss: 9.3073 - val_problems_loss: 7.5083
# Epoch 2/1000
# 162/162 [==============================] - 16s 102ms/step - loss: 17.2266 - completion_loss: 8.6723 - problems_loss: 8.5543 - val_loss: 16.4026 - val_completion_loss: 9.3742 - val_problems_loss: 7.0285
# Epoch 3/1000
# 162/162 [==============================] - 17s 107ms/step - loss: 16.3887 - completion_loss: 8.3870 - problems_loss: 8.0017 - val_loss: 17.0678 - val_completion_loss: 10.0958 - val_problems_loss: 6.9720
# Epoch 4/1000
# 162/162 [==============================] - 16s 97ms/step - loss: 16.3621 - completion_loss: 8.3687 - problems_loss: 7.9934 - val_loss: 16.2261 - val_completion_loss: 9.3633 - val_problems_loss: 6.8629
# Epoch 5/1000
# 162/162 [==============================] - 17s 105ms/step - loss: 15.9408 - completion_loss: 8.1868 - problems_loss: 7.7540 - val_loss: 16.7637 - val_completion_loss: 9.8478 - val_problems_loss: 6.9158
# Epoch 6/1000
# 162/162 [==============================] - 19s 116ms/step - loss: 15.8616 - completion_loss: 8.1210 - problems_loss: 7.7406 - val_loss: 16.8889 - val_completion_loss: 10.1026 - val_problems_loss: 6.7863
# Epoch 7/1000
# 162/162 [==============================] - 19s 116ms/step - loss: 15.6758 - completion_loss: 8.0785 - problems_loss: 7.5974 - val_loss: 17.8468 - val_completion_loss: 10.9657 - val_problems_loss: 6.8812
# Epoch 8/1000
# 162/162 [==============================] - 21s 128ms/step - loss: 15.5044 - completion_loss: 8.0013 - problems_loss: 7.5031 - val_loss: 17.4644 - val_completion_loss: 10.5531 - val_problems_loss: 6.9113
# Epoch 9/1000
# 162/162 [==============================] - 18s 112ms/step - loss: 15.4574 - completion_loss: 7.9438 - problems_loss: 7.5136 - val_loss: 17.3050 - val_completion_loss: 10.5184 - val_problems_loss: 6.7866
# Epoch 10/1000
# 162/162 [==============================] - 19s 119ms/step - loss: 15.1381 - completion_loss: 7.9042 - problems_loss: 7.2339 - val_loss: 18.1641 - val_completion_loss: 11.3177 - val_problems_loss: 6.8464
# Epoch 11/1000
# 162/162 [==============================] - 19s 119ms/step - loss: 15.0437 - completion_loss: 7.8518 - problems_loss: 7.1919 - val_loss: 17.9029 - val_completion_loss: 11.1466 - val_problems_loss: 6.7563
# Epoch 12/1000
# 162/162 [==============================] - 18s 112ms/step - loss: 15.1192 - completion_loss: 7.8057 - problems_loss: 7.3135 - val_loss: 18.1590 - val_completion_loss: 11.4203 - val_problems_loss: 6.7387
# Epoch 13/1000
# 162/162 [==============================] - 20s 126ms/step - loss: 15.0817 - completion_loss: 7.8777 - problems_loss: 7.2040 - val_loss: 18.2066 - val_completion_loss: 11.3672 - val_problems_loss: 6.8394
# Epoch 14/1000
# 162/162 [==============================] - 16s 99ms/step - loss: 15.1402 - completion_loss: 7.7789 - problems_loss: 7.3613 - val_loss: 18.3466 - val_completion_loss: 11.5138 - val_problems_loss: 6.8328
# Epoch 1/1000
# 162/162 [==============================] - 23s 97ms/step - loss: 100.3279 - completion_loss: 9.4388 - problems_loss: 90.8891 - val_loss: 15.7328 - val_completion_loss: 9.3070 - val_problems_loss: 6.4258
# Epoch 2/1000
# 162/162 [==============================] - 14s 87ms/step - loss: 35.3941 - completion_loss: 8.5733 - problems_loss: 26.8207 - val_loss: 15.2214 - val_completion_loss: 9.2593 - val_problems_loss: 5.9621
# Epoch 3/1000
# 162/162 [==============================] - 13s 81ms/step - loss: 34.2869 - completion_loss: 8.3211 - problems_loss: 25.9659 - val_loss: 15.2543 - val_completion_loss: 9.3150 - val_problems_loss: 5.9393
# Epoch 4/1000
# 162/162 [==============================] - 13s 83ms/step - loss: 33.4503 - completion_loss: 8.1847 - problems_loss: 25.2655 - val_loss: 15.2399 - val_completion_loss: 9.1793 - val_problems_loss: 6.0607
# Epoch 5/1000
# 162/162 [==============================] - 14s 87ms/step - loss: 33.2187 - completion_loss: 8.1471 - problems_loss: 25.0715 - val_loss: 15.6983 - val_completion_loss: 9.6060 - val_problems_loss: 6.0923
# Epoch 6/1000
# 162/162 [==============================] - 13s 82ms/step - loss: 32.7397 - completion_loss: 8.0672 - problems_loss: 24.6724 - val_loss: 16.0955 - val_completion_loss: 9.8288 - val_problems_loss: 6.2667
# Epoch 7/1000
# 162/162 [==============================] - 13s 79ms/step - loss: 32.3817 - completion_loss: 7.9406 - problems_loss: 24.4411 - val_loss: 15.8114 - val_completion_loss: 9.3543 - val_problems_loss: 6.4571
# Epoch 8/1000
# 162/162 [==============================] - 12s 76ms/step - loss: 31.9881 - completion_loss: 7.9677 - problems_loss: 24.0204 - val_loss: 16.2027 - val_completion_loss: 9.7657 - val_problems_loss: 6.4371
# Epoch 9/1000
# 162/162 [==============================] - 12s 74ms/step - loss: 31.5707 - completion_loss: 7.8678 - problems_loss: 23.7029 - val_loss: 16.2960 - val_completion_loss: 9.6993 - val_problems_loss: 6.5967
# Epoch 10/1000
# 162/162 [==============================] - 12s 77ms/step - loss: 31.2497 - completion_loss: 7.8812 - problems_loss: 23.3686 - val_loss: 16.7475 - val_completion_loss: 9.7836 - val_problems_loss: 6.9639
# Epoch 11/1000
# 162/162 [==============================] - 13s 80ms/step - loss: 30.3034 - completion_loss: 7.7479 - problems_loss: 22.5555 - val_loss: 16.9587 - val_completion_loss: 9.9147 - val_problems_loss: 7.0440
# Epoch 12/1000
# 162/162 [==============================] - 13s 80ms/step - loss: 30.6905 - completion_loss: 7.7882 - problems_loss: 22.9023 - val_loss: 16.9378 - val_completion_loss: 9.6886 - val_problems_loss: 7.2493
# Epoch 1/1000
# 162/162 [==============================] - 18s 78ms/step - loss: 38.6211 - completion_loss: 9.3484 - problems_loss: 29.2726 - val_loss: 18.9483 - val_completion_loss: 8.5755 - val_problems_loss: 10.3728
# Epoch 2/1000
# 162/162 [==============================] - 13s 83ms/step - loss: 34.2976 - completion_loss: 8.5533 - problems_loss: 25.7443 - val_loss: 18.6874 - val_completion_loss: 8.6037 - val_problems_loss: 10.0837
# Epoch 3/1000
# 162/162 [==============================] - 12s 75ms/step - loss: 33.1820 - completion_loss: 8.3178 - problems_loss: 24.8642 - val_loss: 18.6141 - val_completion_loss: 8.6269 - val_problems_loss: 9.9872
# Epoch 4/1000
# 162/162 [==============================] - 12s 77ms/step - loss: 32.7782 - completion_loss: 8.3168 - problems_loss: 24.4614 - val_loss: 18.9089 - val_completion_loss: 8.8184 - val_problems_loss: 10.0905
# Epoch 5/1000
# 162/162 [==============================] - 13s 81ms/step - loss: 32.5040 - completion_loss: 8.2319 - problems_loss: 24.2721 - val_loss: 19.4006 - val_completion_loss: 9.2096 - val_problems_loss: 10.1910
# Epoch 6/1000
# 162/162 [==============================] - 13s 80ms/step - loss: 31.8647 - completion_loss: 8.0879 - problems_loss: 23.7768 - val_loss: 19.5108 - val_completion_loss: 9.2673 - val_problems_loss: 10.2435
# Epoch 7/1000
# 162/162 [==============================] - 13s 79ms/step - loss: 31.5235 - completion_loss: 8.1103 - problems_loss: 23.4132 - val_loss: 18.9549 - val_completion_loss: 8.7933 - val_problems_loss: 10.1616
# Epoch 8/1000
# 162/162 [==============================] - 13s 82ms/step - loss: 31.5495 - completion_loss: 8.1433 - problems_loss: 23.4062 - val_loss: 18.7258 - val_completion_loss: 8.5870 - val_problems_loss: 10.1388
# Epoch 9/1000
# 162/162 [==============================] - 13s 79ms/step - loss: 30.9870 - completion_loss: 7.9818 - problems_loss: 23.0052 - val_loss: 18.9823 - val_completion_loss: 8.6144 - val_problems_loss: 10.3679
# Epoch 10/1000
# 162/162 [==============================] - 12s 76ms/step - loss: 30.5860 - completion_loss: 8.0389 - problems_loss: 22.5471 - val_loss: 19.3440 - val_completion_loss: 9.0167 - val_problems_loss: 10.3273
# Epoch 11/1000
# 162/162 [==============================] - 13s 82ms/step - loss: 30.0543 - completion_loss: 8.0520 - problems_loss: 22.0024 - val_loss: 19.3951 - val_completion_loss: 9.0644 - val_problems_loss: 10.3307
# Epoch 12/1000
# 162/162 [==============================] - 13s 78ms/step - loss: 30.0264 - completion_loss: 8.0263 - problems_loss: 22.0002 - val_loss: 19.2889 - val_completion_loss: 8.9469 - val_problems_loss: 10.3420
# Epoch 13/1000
# 162/162 [==============================] - 12s 76ms/step - loss: 29.9053 - completion_loss: 7.9184 - problems_loss: 21.9869 - val_loss: 19.2213 - val_completion_loss: 8.9691 - val_problems_loss: 10.2522

# %%
# Load the data

exp_norm_map = pd.read_csv('data/experiment_information/exp_norm_map.csv')
results = pd.read_csv('merged_cross_validation_results.csv')

# %%
# Evaluate the results

norm_exp_dict = defaultdict(lambda: 'None')
for n, e in zip(exp_norm_map['normal_id'], exp_norm_map['experiment_id']):
    norm_exp_dict[n] = e
results['experiment_sequence'] = results['target_sequence'].map(norm_exp_dict)

metrics = []

# Calculate the metrics for each sequence
for sequence, df in results.groupby('target_sequence'):
    
    completion_target = df['completion_target']
    
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)
    
    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([sequence, 
                    norm_exp_dict[sequence], 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])

# Calculate the metrics for each fold
for fold, df in results.groupby('fold'):
    
    completion_target = df['completion_target']
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)
    
    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([f'fold_{fold}', 
                    'None', 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])

# Calculate the metrics for everything combined
completion_target = results['completion_target']
completion_prediction = results['completion_prediction']
completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
completion_mse = mean_squared_error(completion_target, completion_prediction)

problems_target = results[results['completion_target'] == 1]['problems_target']
problems_prediction = results[results['completion_target'] == 1]['problems_prediction']
problems_mae = mean_absolute_error(problems_target, problems_prediction)
problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
problems_mse = mean_squared_error(problems_target, problems_prediction)

metrics.append(['all_target_data', 
                'None', 
                len(results), 
                completion_auc, 
                completion_acc, 
                completion_r2, 
                completion_ev, 
                completion_mse, 
                problems_mae, 
                problems_mape, 
                problems_r2, 
                problems_ev, 
                problems_mse])

metrics = pd.DataFrame(metrics, 
                       columns=['sequence_id', 
                                'experiment_id', 
                                'sample_size', 
                                'completion_auc', 
                                'completion_acc', 
                                'completion_r2', 
                                'completion_ev', 
                                'completion_mse', 
                                'problems_mae', 
                                'problems_mape', 
                                'problems_r2', 
                                'problems_ev', 
                                'problems_mse'])

metrics.to_csv('merged_cross_validation_metrics.csv', index=False)

# %%
metrics.iloc[-6:]
# Out:
#         sequence_id experiment_id  sample_size  completion_auc  \
# 26           fold_0          None         1722        0.722445
# 27           fold_1          None         1722        0.718018
# 28           fold_2          None         1721        0.773003
# 29           fold_3          None         1721        0.731475
# 30           fold_4          None         1721        0.711921
# 31  all_target_data          None         8607        0.730210
#
#     completion_acc  completion_r2  completion_ev  completion_mse  \
# 26        0.704413       0.136081       0.136546        0.186887
# 27        0.746225       0.115982       0.121512        0.174254
# 28        0.771644       0.174369       0.175858        0.154986
# 29        0.757118       0.134823       0.142114        0.171979
# 30        0.747240       0.127299       0.127352        0.176408
# 31        0.745324       0.139281       0.139349        0.172904
#
#     problems_mae  problems_mape  problems_r2  problems_ev  problems_mse
# 26      2.457606       0.213971     0.057924     0.064409     14.747056
# 27      2.199983       0.359514    -0.068016    -0.012085      7.948823
# 28      3.080280       0.207400    -0.029412    -0.016144     83.572682
# 29      2.241908       0.266352     0.042353     0.043226     11.474542
# 30      2.087260       0.264356     0.011434     0.016705      8.411141
# 31      2.417625       0.262638    -0.003937    -0.003671     25.745528
