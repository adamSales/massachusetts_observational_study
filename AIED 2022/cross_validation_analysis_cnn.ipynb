# %%
import os
import numpy as np
import pandas as pd
import hickle as hkl

from collections import defaultdict

from sklearn.metrics import roc_auc_score, r2_score, accuracy_score, explained_variance_score, mean_absolute_error, mean_squared_error

import keras
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout, Dense, MaxPooling1D, Conv1D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

from IPython.core.display import display, HTML



# Hide GPU from visible devices

#'''
tf.config.set_visible_devices([], 'GPU')
print(f'CUDA GPU AVAILABLE: {tf.test.is_gpu_available(cuda_only=True)}')
'''
THREADS = 8
os.environ['OMP_NUM_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTEROP_THREADS'] = str(THREADS)
os.environ['TF_NUM_INTRAOP_THREADS'] = str(THREADS)
tf.config.threading.set_inter_op_parallelism_threads(THREADS)
tf.config.threading.set_intra_op_parallelism_threads(THREADS)
tf.config.set_soft_device_placement(True)
'''

#'''
display(HTML("<style>.container { width:100% !important; }</style>"))
#'''
# Out:
# WARNING:tensorflow:From <ipython-input-1-7c3d340a8ac8>:25: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# CUDA GPU AVAILABLE: True
# <style>.container { width:100% !important; }</style>

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean((y_pred - y_true) / y_true)

# %%
N_SPLITS = 5
N_STEPS = 20
N_DAYS = 60
DATA_DIR = f'data/processed_data/cv_data__{N_SPLITS}_class_id_folds__{N_STEPS}_steps__{N_DAYS}_days'

# %%
results = []

for i in range(N_SPLITS):

    # Load one partition of folds
    data = hkl.load(f'{DATA_DIR}/fold_{i}.hkl')
    action_training_input = data['action_training_input']
    recurrent_training_input = data['recurrent_training_input']
    prior_training_input = data['prior_training_input']
    completion_training_target = data['completion_training_target']
    problems_training_target = data['problems_training_target']
    training_target_sequence = data['training_target_sequence']
    action_testing_input = data['action_testing_input']
    recurrent_testing_input = data['recurrent_testing_input']
    prior_testing_input = data['prior_testing_input']
    completion_testing_target = data['completion_testing_target']
    problems_testing_target = data['problems_testing_target']
    testing_target_sequence = data['testing_target_sequence']
    
    # Clear session so models don't pile up
    keras.backend.clear_session()
    
    # Recurrent Input
    recurrent_input_layer = Input(shape=recurrent_training_input[0].shape, name='recurrent')
    recurrent_model = Conv1D(filters=128, kernel_size=3, activation='relu')(recurrent_input_layer)
    recurrent_model = MaxPooling1D(pool_size=2)(recurrent_model)
    recurrent_model = Dropout(0.5)(recurrent_model)
    recurrent_model = Conv1D(filters=64, kernel_size=3, activation='relu')(recurrent_model)
    recurrent_model = MaxPooling1D(pool_size=2)(recurrent_model)
    recurrent_model = Flatten()(recurrent_model)
    recurrent_model = Dropout(0.5)(recurrent_model)
    recurrent_model = Dense(units=32, activation='relu')(recurrent_model)
    recurrent_model = Dropout(0.5)(recurrent_model)
    completion_output_layer = Dense(units=1, activation='sigmoid', name='completion')(recurrent_model)
    problems_output_layer = Dense(units=1, activation='linear', name='problems')(recurrent_model)
    
    combined_model = Model(recurrent_input_layer, [completion_output_layer, problems_output_layer])
    combined_model.compile(optimizer=Adam(learning_rate=1e-4), loss={'completion': 'binary_crossentropy', 'problems': 'mse'})

    # Train model
    es = [EarlyStopping(monitor='val_loss', patience=10, min_delta=0, restore_best_weights=True)]
    weights = {'completion': np.ones_like(completion_training_target) * 16, 'problems': completion_training_target}
    combined_model.fit(x={'recurrent': recurrent_training_input},
                       y={'completion': completion_training_target, 'problems': problems_training_target},
                       epochs=1000,
                       validation_split=0.25,
                       callbacks=es,
                       sample_weight=weights,
                       verbose=1)
    
    # Store model predictions
    completion_testing_output, problems_testing_output = combined_model.predict({'recurrent': recurrent_testing_input})
    df = pd.DataFrame(zip(np.ones_like(testing_target_sequence).flatten() * i, 
                          testing_target_sequence.flatten(), 
                          completion_testing_target.flatten(), 
                          problems_testing_target.flatten(), 
                          completion_testing_output.flatten(), 
                          problems_testing_output.flatten()), 
                      columns = ['fold', 
                                 'target_sequence', 
                                 'completion_target', 
                                 'problems_target', 
                                 'completion_prediction', 
                                 'problems_prediction'])
    results.append(df)
    

pd.concat(results).to_csv('cnn_cross_validation_results.csv', index=False)
# Out:
# Epoch 1/1000
# 3949/3949 [==============================] - 47s 12ms/step - loss: 19.1141 - completion_loss: 9.2603 - problems_loss: 9.8538 - val_loss: 16.6781 - val_completion_loss: 9.3097 - val_problems_loss: 7.3683
# Epoch 2/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 16.8470 - completion_loss: 8.5842 - problems_loss: 8.2628 - val_loss: 16.0310 - val_completion_loss: 9.1806 - val_problems_loss: 6.8504
# Epoch 3/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 16.3917 - completion_loss: 8.4173 - problems_loss: 7.9744 - val_loss: 15.9654 - val_completion_loss: 9.1133 - val_problems_loss: 6.8521
# Epoch 4/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 16.0691 - completion_loss: 8.3096 - problems_loss: 7.7595 - val_loss: 15.6745 - val_completion_loss: 9.0845 - val_problems_loss: 6.5900
# Epoch 5/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 15.8467 - completion_loss: 8.2388 - problems_loss: 7.6079 - val_loss: 15.5523 - val_completion_loss: 9.0237 - val_problems_loss: 6.5287
# Epoch 6/1000
# 3949/3949 [==============================] - 48s 12ms/step - loss: 15.6643 - completion_loss: 8.1747 - problems_loss: 7.4896 - val_loss: 15.3005 - val_completion_loss: 9.0153 - val_problems_loss: 6.2853
# Epoch 7/1000
# 3949/3949 [==============================] - 40s 10ms/step - loss: 15.5395 - completion_loss: 8.1090 - problems_loss: 7.4304 - val_loss: 15.1937 - val_completion_loss: 8.9985 - val_problems_loss: 6.1952
# Epoch 8/1000
# 3949/3949 [==============================] - 42s 11ms/step - loss: 15.3964 - completion_loss: 8.0462 - problems_loss: 7.3502 - val_loss: 15.1476 - val_completion_loss: 8.9768 - val_problems_loss: 6.1708
# Epoch 9/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 15.2468 - completion_loss: 8.0102 - problems_loss: 7.2365 - val_loss: 15.1391 - val_completion_loss: 8.9886 - val_problems_loss: 6.1505
# Epoch 10/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 15.1618 - completion_loss: 7.9577 - problems_loss: 7.2041 - val_loss: 15.1371 - val_completion_loss: 8.9766 - val_problems_loss: 6.1605
# Epoch 11/1000
# 3949/3949 [==============================] - 39s 10ms/step - loss: 15.0447 - completion_loss: 7.9270 - problems_loss: 7.1176 - val_loss: 15.0255 - val_completion_loss: 8.9859 - val_problems_loss: 6.0397
# Epoch 12/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 14.9302 - completion_loss: 7.8775 - problems_loss: 7.0527 - val_loss: 14.9293 - val_completion_loss: 8.9845 - val_problems_loss: 5.9448
# Epoch 13/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.8549 - completion_loss: 7.8404 - problems_loss: 7.0145 - val_loss: 14.9216 - val_completion_loss: 9.0118 - val_problems_loss: 5.9098
# Epoch 14/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 14.7708 - completion_loss: 7.8162 - problems_loss: 6.9546 - val_loss: 15.0185 - val_completion_loss: 8.9950 - val_problems_loss: 6.0234
# Epoch 15/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.7002 - completion_loss: 7.7799 - problems_loss: 6.9203 - val_loss: 14.9543 - val_completion_loss: 9.0210 - val_problems_loss: 5.9333
# Epoch 16/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.6113 - completion_loss: 7.7572 - problems_loss: 6.8541 - val_loss: 14.9073 - val_completion_loss: 9.0210 - val_problems_loss: 5.8863
# Epoch 17/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.5849 - completion_loss: 7.7300 - problems_loss: 6.8548 - val_loss: 14.9216 - val_completion_loss: 9.0027 - val_problems_loss: 5.9189
# Epoch 18/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.4666 - completion_loss: 7.6816 - problems_loss: 6.7851 - val_loss: 14.9080 - val_completion_loss: 9.0272 - val_problems_loss: 5.8808
# Epoch 19/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.4250 - completion_loss: 7.6478 - problems_loss: 6.7772 - val_loss: 14.9833 - val_completion_loss: 9.0403 - val_problems_loss: 5.9430
# Epoch 20/1000
# 3949/3949 [==============================] - 40s 10ms/step - loss: 14.3730 - completion_loss: 7.6307 - problems_loss: 6.7423 - val_loss: 14.9480 - val_completion_loss: 9.0429 - val_problems_loss: 5.9051
# Epoch 21/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 14.3203 - completion_loss: 7.6172 - problems_loss: 6.7031 - val_loss: 14.9533 - val_completion_loss: 9.0412 - val_problems_loss: 5.9121
# Epoch 22/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.2428 - completion_loss: 7.5914 - problems_loss: 6.6514 - val_loss: 14.9550 - val_completion_loss: 9.0702 - val_problems_loss: 5.8847
# Epoch 23/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 14.2230 - completion_loss: 7.5679 - problems_loss: 6.6550 - val_loss: 14.9620 - val_completion_loss: 9.0743 - val_problems_loss: 5.8876
# Epoch 24/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 14.1439 - completion_loss: 7.5413 - problems_loss: 6.6025 - val_loss: 14.9198 - val_completion_loss: 9.0622 - val_problems_loss: 5.8576
# Epoch 25/1000
# 3949/3949 [==============================] - 39s 10ms/step - loss: 14.1530 - completion_loss: 7.5342 - problems_loss: 6.6188 - val_loss: 14.9719 - val_completion_loss: 9.0884 - val_problems_loss: 5.8836
# Epoch 26/1000
# 3949/3949 [==============================] - 39s 10ms/step - loss: 14.0906 - completion_loss: 7.5087 - problems_loss: 6.5818 - val_loss: 14.9684 - val_completion_loss: 9.1062 - val_problems_loss: 5.8622
# Epoch 1/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 18.1680 - completion_loss: 9.2106 - problems_loss: 8.9574 - val_loss: 16.0946 - val_completion_loss: 9.1683 - val_problems_loss: 6.9263
# Epoch 2/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 16.1486 - completion_loss: 8.5914 - problems_loss: 7.5571 - val_loss: 15.6060 - val_completion_loss: 9.0316 - val_problems_loss: 6.5745
# Epoch 3/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 15.7227 - completion_loss: 8.4185 - problems_loss: 7.3042 - val_loss: 15.2974 - val_completion_loss: 8.9637 - val_problems_loss: 6.3337
# Epoch 4/1000
# 3949/3949 [==============================] - 59s 15ms/step - loss: 15.4343 - completion_loss: 8.3000 - problems_loss: 7.1342 - val_loss: 15.2267 - val_completion_loss: 8.9326 - val_problems_loss: 6.2942
# Epoch 5/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 15.2269 - completion_loss: 8.2072 - problems_loss: 7.0196 - val_loss: 15.1404 - val_completion_loss: 8.9105 - val_problems_loss: 6.2299
# Epoch 6/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 15.1287 - completion_loss: 8.1575 - problems_loss: 6.9711 - val_loss: 14.9761 - val_completion_loss: 8.8942 - val_problems_loss: 6.0818
# Epoch 7/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 14.9620 - completion_loss: 8.0992 - problems_loss: 6.8629 - val_loss: 14.8197 - val_completion_loss: 8.8716 - val_problems_loss: 5.9481
# Epoch 8/1000
# 3949/3949 [==============================] - 51s 13ms/step - loss: 14.8468 - completion_loss: 8.0403 - problems_loss: 6.8065 - val_loss: 14.8003 - val_completion_loss: 8.8803 - val_problems_loss: 5.9199
# Epoch 9/1000
# 3949/3949 [==============================] - 53s 13ms/step - loss: 14.7387 - completion_loss: 7.9948 - problems_loss: 6.7438 - val_loss: 14.7661 - val_completion_loss: 8.8761 - val_problems_loss: 5.8900
# Epoch 10/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.6457 - completion_loss: 7.9576 - problems_loss: 6.6881 - val_loss: 14.7644 - val_completion_loss: 8.8956 - val_problems_loss: 5.8688
# Epoch 11/1000
# 3949/3949 [==============================] - 53s 14ms/step - loss: 14.5678 - completion_loss: 7.9243 - problems_loss: 6.6435 - val_loss: 14.7170 - val_completion_loss: 8.8595 - val_problems_loss: 5.8575
# Epoch 12/1000
# 3949/3949 [==============================] - 53s 13ms/step - loss: 14.4542 - completion_loss: 7.8575 - problems_loss: 6.5967 - val_loss: 14.6427 - val_completion_loss: 8.8611 - val_problems_loss: 5.7816
# Epoch 13/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.4135 - completion_loss: 7.8546 - problems_loss: 6.5588 - val_loss: 14.6652 - val_completion_loss: 8.8673 - val_problems_loss: 5.7979
# Epoch 14/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 14.3103 - completion_loss: 7.8069 - problems_loss: 6.5034 - val_loss: 14.6801 - val_completion_loss: 8.8652 - val_problems_loss: 5.8148
# Epoch 15/1000
# 3949/3949 [==============================] - 53s 14ms/step - loss: 14.2460 - completion_loss: 7.7739 - problems_loss: 6.4721 - val_loss: 14.6156 - val_completion_loss: 8.8730 - val_problems_loss: 5.7426
# Epoch 16/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.1829 - completion_loss: 7.7447 - problems_loss: 6.4381 - val_loss: 14.6197 - val_completion_loss: 8.8627 - val_problems_loss: 5.7570
# Epoch 17/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.1232 - completion_loss: 7.7168 - problems_loss: 6.4064 - val_loss: 14.6081 - val_completion_loss: 8.8713 - val_problems_loss: 5.7368
# Epoch 18/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.0723 - completion_loss: 7.6986 - problems_loss: 6.3737 - val_loss: 14.6319 - val_completion_loss: 8.8883 - val_problems_loss: 5.7436
# Epoch 19/1000
# 3949/3949 [==============================] - 53s 13ms/step - loss: 14.0172 - completion_loss: 7.6719 - problems_loss: 6.3453 - val_loss: 14.6654 - val_completion_loss: 8.9297 - val_problems_loss: 5.7357
# Epoch 20/1000
# 3949/3949 [==============================] - 52s 13ms/step - loss: 13.9770 - completion_loss: 7.6536 - problems_loss: 6.3234 - val_loss: 14.6547 - val_completion_loss: 8.9057 - val_problems_loss: 5.7490
# Epoch 21/1000
# 3949/3949 [==============================] - 48s 12ms/step - loss: 13.9160 - completion_loss: 7.6291 - problems_loss: 6.2869 - val_loss: 14.6340 - val_completion_loss: 8.9032 - val_problems_loss: 5.7307
# Epoch 22/1000
# 3949/3949 [==============================] - 38s 10ms/step - loss: 13.8708 - completion_loss: 7.6040 - problems_loss: 6.2668 - val_loss: 14.6478 - val_completion_loss: 8.9102 - val_problems_loss: 5.7376
# Epoch 23/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 13.8281 - completion_loss: 7.5769 - problems_loss: 6.2511 - val_loss: 14.6436 - val_completion_loss: 8.9376 - val_problems_loss: 5.7060
# Epoch 24/1000
# 3949/3949 [==============================] - 37s 9ms/step - loss: 13.7725 - completion_loss: 7.5585 - problems_loss: 6.2140 - val_loss: 14.6489 - val_completion_loss: 8.9328 - val_problems_loss: 5.7161
# Epoch 25/1000
# 3949/3949 [==============================] - 48s 12ms/step - loss: 13.7195 - completion_loss: 7.5345 - problems_loss: 6.1850 - val_loss: 14.6655 - val_completion_loss: 8.9557 - val_problems_loss: 5.7097
# Epoch 26/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 13.7050 - completion_loss: 7.5422 - problems_loss: 6.1628 - val_loss: 14.6580 - val_completion_loss: 8.9473 - val_problems_loss: 5.7107
# Epoch 27/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 13.6526 - completion_loss: 7.4940 - problems_loss: 6.1587 - val_loss: 14.6883 - val_completion_loss: 8.9538 - val_problems_loss: 5.7345
# Epoch 1/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 18.8628 - completion_loss: 9.4576 - problems_loss: 9.4052 - val_loss: 16.6444 - val_completion_loss: 9.1131 - val_problems_loss: 7.5313
# Epoch 2/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 16.3646 - completion_loss: 8.6901 - problems_loss: 7.6744 - val_loss: 16.0438 - val_completion_loss: 8.9624 - val_problems_loss: 7.0814
# Epoch 3/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 15.8590 - completion_loss: 8.5149 - problems_loss: 7.3442 - val_loss: 15.5994 - val_completion_loss: 8.8907 - val_problems_loss: 6.7086
# Epoch 4/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 15.5472 - completion_loss: 8.4193 - problems_loss: 7.1279 - val_loss: 15.6349 - val_completion_loss: 8.8848 - val_problems_loss: 6.7501
# Epoch 5/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 15.2642 - completion_loss: 8.3274 - problems_loss: 6.9369 - val_loss: 15.4996 - val_completion_loss: 8.8572 - val_problems_loss: 6.6424
# Epoch 6/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 15.0845 - completion_loss: 8.2660 - problems_loss: 6.8185 - val_loss: 15.2678 - val_completion_loss: 8.7921 - val_problems_loss: 6.4757
# Epoch 7/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 14.9357 - completion_loss: 8.2191 - problems_loss: 6.7166 - val_loss: 15.1269 - val_completion_loss: 8.8221 - val_problems_loss: 6.3049
# Epoch 8/1000
# 3949/3949 [==============================] - 52s 13ms/step - loss: 14.8081 - completion_loss: 8.1468 - problems_loss: 6.6612 - val_loss: 15.1885 - val_completion_loss: 8.7968 - val_problems_loss: 6.3916
# Epoch 9/1000
# 3949/3949 [==============================] - 53s 14ms/step - loss: 14.6595 - completion_loss: 8.1073 - problems_loss: 6.5522 - val_loss: 15.2012 - val_completion_loss: 8.7728 - val_problems_loss: 6.4284
# Epoch 10/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.5580 - completion_loss: 8.0623 - problems_loss: 6.4957 - val_loss: 15.0085 - val_completion_loss: 8.7711 - val_problems_loss: 6.2374
# Epoch 11/1000
# 3949/3949 [==============================] - 52s 13ms/step - loss: 14.4387 - completion_loss: 8.0062 - problems_loss: 6.4324 - val_loss: 14.9817 - val_completion_loss: 8.7657 - val_problems_loss: 6.2160
# Epoch 12/1000
# 3949/3949 [==============================] - 52s 13ms/step - loss: 14.3589 - completion_loss: 7.9580 - problems_loss: 6.4008 - val_loss: 14.9072 - val_completion_loss: 8.7277 - val_problems_loss: 6.1794
# Epoch 13/1000
# 3949/3949 [==============================] - 50s 13ms/step - loss: 14.2538 - completion_loss: 7.9476 - problems_loss: 6.3061 - val_loss: 14.9417 - val_completion_loss: 8.7621 - val_problems_loss: 6.1796
# Epoch 14/1000
# 3949/3949 [==============================] - 48s 12ms/step - loss: 14.1767 - completion_loss: 7.8826 - problems_loss: 6.2940 - val_loss: 14.9485 - val_completion_loss: 8.7585 - val_problems_loss: 6.1900
# Epoch 15/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 14.0580 - completion_loss: 7.8401 - problems_loss: 6.2179 - val_loss: 14.8318 - val_completion_loss: 8.7532 - val_problems_loss: 6.0786
# Epoch 16/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.9767 - completion_loss: 7.8066 - problems_loss: 6.1700 - val_loss: 14.8253 - val_completion_loss: 8.7442 - val_problems_loss: 6.0811
# Epoch 17/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.9173 - completion_loss: 7.7607 - problems_loss: 6.1566 - val_loss: 14.8599 - val_completion_loss: 8.7652 - val_problems_loss: 6.0948
# Epoch 18/1000
# 3949/3949 [==============================] - 63s 16ms/step - loss: 13.8641 - completion_loss: 7.7382 - problems_loss: 6.1258 - val_loss: 14.8757 - val_completion_loss: 8.7808 - val_problems_loss: 6.0949
# Epoch 19/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 13.8024 - completion_loss: 7.7151 - problems_loss: 6.0873 - val_loss: 14.8615 - val_completion_loss: 8.7823 - val_problems_loss: 6.0791
# Epoch 20/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.7558 - completion_loss: 7.6882 - problems_loss: 6.0675 - val_loss: 14.8103 - val_completion_loss: 8.7689 - val_problems_loss: 6.0414
# Epoch 21/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 13.7050 - completion_loss: 7.6690 - problems_loss: 6.0360 - val_loss: 14.8244 - val_completion_loss: 8.7978 - val_problems_loss: 6.0266
# Epoch 22/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.6302 - completion_loss: 7.6310 - problems_loss: 5.9991 - val_loss: 14.8283 - val_completion_loss: 8.7762 - val_problems_loss: 6.0521
# Epoch 23/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.5679 - completion_loss: 7.5924 - problems_loss: 5.9755 - val_loss: 14.8278 - val_completion_loss: 8.7972 - val_problems_loss: 6.0306
# Epoch 24/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.5319 - completion_loss: 7.5903 - problems_loss: 5.9416 - val_loss: 14.8407 - val_completion_loss: 8.8437 - val_problems_loss: 5.9970
# Epoch 25/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.4925 - completion_loss: 7.5488 - problems_loss: 5.9437 - val_loss: 14.8435 - val_completion_loss: 8.8332 - val_problems_loss: 6.0103
# Epoch 26/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 13.4440 - completion_loss: 7.5223 - problems_loss: 5.9218 - val_loss: 14.9090 - val_completion_loss: 8.8648 - val_problems_loss: 6.0442
# Epoch 27/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.4205 - completion_loss: 7.5322 - problems_loss: 5.8884 - val_loss: 14.8246 - val_completion_loss: 8.8270 - val_problems_loss: 5.9975
# Epoch 28/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 13.3708 - completion_loss: 7.4968 - problems_loss: 5.8741 - val_loss: 14.8511 - val_completion_loss: 8.8633 - val_problems_loss: 5.9878
# Epoch 29/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 13.3263 - completion_loss: 7.4840 - problems_loss: 5.8422 - val_loss: 14.8378 - val_completion_loss: 8.8443 - val_problems_loss: 5.9935
# Epoch 30/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 13.2986 - completion_loss: 7.4494 - problems_loss: 5.8492 - val_loss: 14.8686 - val_completion_loss: 8.8550 - val_problems_loss: 6.0136
# Epoch 1/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 19.1903 - completion_loss: 9.4393 - problems_loss: 9.7509 - val_loss: 16.2692 - val_completion_loss: 9.1047 - val_problems_loss: 7.1645
# Epoch 2/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 16.6938 - completion_loss: 8.6023 - problems_loss: 8.0915 - val_loss: 15.8349 - val_completion_loss: 8.9510 - val_problems_loss: 6.8839
# Epoch 3/1000
# 3949/3949 [==============================] - 57s 15ms/step - loss: 16.1618 - completion_loss: 8.4079 - problems_loss: 7.7539 - val_loss: 15.6351 - val_completion_loss: 8.9207 - val_problems_loss: 6.7143
# Epoch 4/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 15.8731 - completion_loss: 8.3028 - problems_loss: 7.5702 - val_loss: 15.4431 - val_completion_loss: 8.8861 - val_problems_loss: 6.5571
# Epoch 5/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 15.6380 - completion_loss: 8.2008 - problems_loss: 7.4372 - val_loss: 15.3948 - val_completion_loss: 8.8634 - val_problems_loss: 6.5315
# Epoch 6/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 15.4754 - completion_loss: 8.1504 - problems_loss: 7.3250 - val_loss: 15.3728 - val_completion_loss: 8.8435 - val_problems_loss: 6.5293
# Epoch 7/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 15.3426 - completion_loss: 8.0977 - problems_loss: 7.2449 - val_loss: 15.1421 - val_completion_loss: 8.8375 - val_problems_loss: 6.3047
# Epoch 8/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 15.2026 - completion_loss: 8.0385 - problems_loss: 7.1641 - val_loss: 15.0317 - val_completion_loss: 8.7783 - val_problems_loss: 6.2534
# Epoch 9/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 15.1099 - completion_loss: 7.9989 - problems_loss: 7.1111 - val_loss: 15.0564 - val_completion_loss: 8.8041 - val_problems_loss: 6.2523
# Epoch 10/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 14.9805 - completion_loss: 7.9550 - problems_loss: 7.0254 - val_loss: 14.9667 - val_completion_loss: 8.7947 - val_problems_loss: 6.1721
# Epoch 11/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.9192 - completion_loss: 7.9019 - problems_loss: 7.0173 - val_loss: 14.9305 - val_completion_loss: 8.7917 - val_problems_loss: 6.1388
# Epoch 12/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 14.8094 - completion_loss: 7.8667 - problems_loss: 6.9428 - val_loss: 14.9961 - val_completion_loss: 8.8178 - val_problems_loss: 6.1783
# Epoch 13/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 14.7619 - completion_loss: 7.8452 - problems_loss: 6.9167 - val_loss: 14.8332 - val_completion_loss: 8.7749 - val_problems_loss: 6.0583
# Epoch 14/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 14.6686 - completion_loss: 7.8100 - problems_loss: 6.8586 - val_loss: 14.9020 - val_completion_loss: 8.8192 - val_problems_loss: 6.0828
# Epoch 15/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 14.6152 - completion_loss: 7.7797 - problems_loss: 6.8355 - val_loss: 14.8566 - val_completion_loss: 8.8100 - val_problems_loss: 6.0467
# Epoch 16/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 14.5260 - completion_loss: 7.7390 - problems_loss: 6.7870 - val_loss: 14.8808 - val_completion_loss: 8.8213 - val_problems_loss: 6.0595
# Epoch 17/1000
# 3949/3949 [==============================] - 62s 16ms/step - loss: 14.4838 - completion_loss: 7.7298 - problems_loss: 6.7541 - val_loss: 14.8240 - val_completion_loss: 8.7893 - val_problems_loss: 6.0347
# Epoch 18/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 14.4171 - completion_loss: 7.6909 - problems_loss: 6.7262 - val_loss: 14.8449 - val_completion_loss: 8.7942 - val_problems_loss: 6.0507
# Epoch 19/1000
# 3949/3949 [==============================] - 63s 16ms/step - loss: 14.3651 - completion_loss: 7.6543 - problems_loss: 6.7107 - val_loss: 14.8725 - val_completion_loss: 8.8060 - val_problems_loss: 6.0664
# Epoch 20/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.3187 - completion_loss: 7.6424 - problems_loss: 6.6763 - val_loss: 14.8372 - val_completion_loss: 8.8062 - val_problems_loss: 6.0310
# Epoch 21/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 14.2248 - completion_loss: 7.5962 - problems_loss: 6.6286 - val_loss: 14.7763 - val_completion_loss: 8.8144 - val_problems_loss: 5.9618
# Epoch 22/1000
# 3949/3949 [==============================] - 59s 15ms/step - loss: 14.1865 - completion_loss: 7.5781 - problems_loss: 6.6084 - val_loss: 14.8225 - val_completion_loss: 8.8315 - val_problems_loss: 5.9910
# Epoch 23/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.1593 - completion_loss: 7.5804 - problems_loss: 6.5788 - val_loss: 14.8374 - val_completion_loss: 8.8287 - val_problems_loss: 6.0087
# Epoch 24/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.0925 - completion_loss: 7.5304 - problems_loss: 6.5621 - val_loss: 14.8154 - val_completion_loss: 8.8307 - val_problems_loss: 5.9847
# Epoch 25/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.0432 - completion_loss: 7.5166 - problems_loss: 6.5266 - val_loss: 14.8084 - val_completion_loss: 8.8375 - val_problems_loss: 5.9709
# Epoch 26/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 13.9957 - completion_loss: 7.5044 - problems_loss: 6.4913 - val_loss: 14.8241 - val_completion_loss: 8.8375 - val_problems_loss: 5.9866
# Epoch 27/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 13.9947 - completion_loss: 7.4742 - problems_loss: 6.5205 - val_loss: 14.8006 - val_completion_loss: 8.8378 - val_problems_loss: 5.9628
# Epoch 28/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 13.9713 - completion_loss: 7.4868 - problems_loss: 6.4845 - val_loss: 14.8394 - val_completion_loss: 8.8644 - val_problems_loss: 5.9750
# Epoch 29/1000
# 3949/3949 [==============================] - 56s 14ms/step - loss: 13.9478 - completion_loss: 7.4595 - problems_loss: 6.4884 - val_loss: 14.8273 - val_completion_loss: 8.8409 - val_problems_loss: 5.9865
# Epoch 30/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 13.8956 - completion_loss: 7.4511 - problems_loss: 6.4446 - val_loss: 14.8416 - val_completion_loss: 8.8669 - val_problems_loss: 5.9747
# Epoch 31/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.8617 - completion_loss: 7.4206 - problems_loss: 6.4411 - val_loss: 14.8400 - val_completion_loss: 8.8671 - val_problems_loss: 5.9729
# Epoch 1/1000
# 3949/3949 [==============================] - 68s 17ms/step - loss: 19.0770 - completion_loss: 9.2700 - problems_loss: 9.8070 - val_loss: 16.1451 - val_completion_loss: 9.2373 - val_problems_loss: 6.9077
# Epoch 2/1000
# 3949/3949 [==============================] - 63s 16ms/step - loss: 16.6664 - completion_loss: 8.5727 - problems_loss: 8.0937 - val_loss: 15.8560 - val_completion_loss: 9.0789 - val_problems_loss: 6.7771
# Epoch 3/1000
# 3949/3949 [==============================] - 62s 16ms/step - loss: 16.2099 - completion_loss: 8.3805 - problems_loss: 7.8294 - val_loss: 15.5033 - val_completion_loss: 8.9993 - val_problems_loss: 6.5040
# Epoch 4/1000
# 3949/3949 [==============================] - 59s 15ms/step - loss: 15.8782 - completion_loss: 8.2759 - problems_loss: 7.6022 - val_loss: 15.3297 - val_completion_loss: 8.9104 - val_problems_loss: 6.4193
# Epoch 5/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 15.6482 - completion_loss: 8.2179 - problems_loss: 7.4303 - val_loss: 15.1572 - val_completion_loss: 8.9294 - val_problems_loss: 6.2277
# Epoch 6/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 15.4958 - completion_loss: 8.1524 - problems_loss: 7.3434 - val_loss: 15.0275 - val_completion_loss: 8.9105 - val_problems_loss: 6.1170
# Epoch 7/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 15.3644 - completion_loss: 8.0899 - problems_loss: 7.2745 - val_loss: 14.9977 - val_completion_loss: 8.9067 - val_problems_loss: 6.0910
# Epoch 8/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 15.2442 - completion_loss: 8.0348 - problems_loss: 7.2094 - val_loss: 15.0139 - val_completion_loss: 8.8927 - val_problems_loss: 6.1212
# Epoch 9/1000
# 3949/3949 [==============================] - 58s 15ms/step - loss: 15.1463 - completion_loss: 7.9787 - problems_loss: 7.1676 - val_loss: 14.9618 - val_completion_loss: 8.9131 - val_problems_loss: 6.0487
# Epoch 10/1000
# 3949/3949 [==============================] - 62s 16ms/step - loss: 15.0172 - completion_loss: 7.9423 - problems_loss: 7.0749 - val_loss: 14.6934 - val_completion_loss: 8.8808 - val_problems_loss: 5.8126
# Epoch 11/1000
# 3949/3949 [==============================] - 59s 15ms/step - loss: 14.9215 - completion_loss: 7.9030 - problems_loss: 7.0185 - val_loss: 14.8307 - val_completion_loss: 8.8676 - val_problems_loss: 5.9631
# Epoch 12/1000
# 3949/3949 [==============================] - 59s 15ms/step - loss: 14.8587 - completion_loss: 7.8707 - problems_loss: 6.9880 - val_loss: 14.8235 - val_completion_loss: 8.8856 - val_problems_loss: 5.9379
# Epoch 13/1000
# 3949/3949 [==============================] - 55s 14ms/step - loss: 14.7434 - completion_loss: 7.8356 - problems_loss: 6.9078 - val_loss: 14.7153 - val_completion_loss: 8.8962 - val_problems_loss: 5.8190
# Epoch 14/1000
# 3949/3949 [==============================] - 57s 14ms/step - loss: 14.6591 - completion_loss: 7.7862 - problems_loss: 6.8729 - val_loss: 14.7509 - val_completion_loss: 8.9232 - val_problems_loss: 5.8276
# Epoch 15/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.6174 - completion_loss: 7.7577 - problems_loss: 6.8598 - val_loss: 14.6705 - val_completion_loss: 8.8782 - val_problems_loss: 5.7924
# Epoch 16/1000
# 3949/3949 [==============================] - 61s 16ms/step - loss: 14.5110 - completion_loss: 7.7272 - problems_loss: 6.7838 - val_loss: 14.6608 - val_completion_loss: 8.8933 - val_problems_loss: 5.7675
# Epoch 17/1000
# 3949/3949 [==============================] - 61s 16ms/step - loss: 14.4562 - completion_loss: 7.7050 - problems_loss: 6.7512 - val_loss: 14.6691 - val_completion_loss: 8.9125 - val_problems_loss: 5.7566
# Epoch 18/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 14.4100 - completion_loss: 7.6760 - problems_loss: 6.7340 - val_loss: 14.7100 - val_completion_loss: 8.9049 - val_problems_loss: 5.8051
# Epoch 19/1000
# 3949/3949 [==============================] - 61s 16ms/step - loss: 14.3455 - completion_loss: 7.6503 - problems_loss: 6.6953 - val_loss: 14.6065 - val_completion_loss: 8.8904 - val_problems_loss: 5.7161
# Epoch 20/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.2864 - completion_loss: 7.6244 - problems_loss: 6.6620 - val_loss: 14.6482 - val_completion_loss: 8.9049 - val_problems_loss: 5.7433
# Epoch 21/1000
# 3949/3949 [==============================] - 60s 15ms/step - loss: 14.2458 - completion_loss: 7.6047 - problems_loss: 6.6411 - val_loss: 14.6315 - val_completion_loss: 8.9106 - val_problems_loss: 5.7209
# Epoch 22/1000
# 3949/3949 [==============================] - 64s 16ms/step - loss: 14.1730 - completion_loss: 7.5641 - problems_loss: 6.6089 - val_loss: 14.6188 - val_completion_loss: 8.9044 - val_problems_loss: 5.7144
# Epoch 23/1000
# 3949/3949 [==============================] - 63s 16ms/step - loss: 14.1073 - completion_loss: 7.5438 - problems_loss: 6.5634 - val_loss: 14.6472 - val_completion_loss: 8.9512 - val_problems_loss: 5.6960
# Epoch 24/1000
# 3949/3949 [==============================] - 61s 16ms/step - loss: 14.0935 - completion_loss: 7.5135 - problems_loss: 6.5800 - val_loss: 14.7147 - val_completion_loss: 8.9673 - val_problems_loss: 5.7474
# Epoch 25/1000
# 3949/3949 [==============================] - 63s 16ms/step - loss: 14.0627 - completion_loss: 7.5237 - problems_loss: 6.5390 - val_loss: 14.6111 - val_completion_loss: 8.9260 - val_problems_loss: 5.6852
# Epoch 26/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.9735 - completion_loss: 7.4975 - problems_loss: 6.4760 - val_loss: 14.6324 - val_completion_loss: 8.9592 - val_problems_loss: 5.6732
# Epoch 27/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.9410 - completion_loss: 7.4559 - problems_loss: 6.4851 - val_loss: 14.6487 - val_completion_loss: 8.9443 - val_problems_loss: 5.7044
# Epoch 28/1000
# 3949/3949 [==============================] - 61s 15ms/step - loss: 13.9032 - completion_loss: 7.4555 - problems_loss: 6.4477 - val_loss: 14.6557 - val_completion_loss: 8.9653 - val_problems_loss: 5.6904
# Epoch 29/1000
# 3949/3949 [==============================] - 54s 14ms/step - loss: 13.9055 - completion_loss: 7.4400 - problems_loss: 6.4655 - val_loss: 14.7022 - val_completion_loss: 8.9970 - val_problems_loss: 5.7052

# %%
# Load the data

exp_norm_map = pd.read_csv('data/experiment_information/exp_norm_map.csv')
results = pd.read_csv('cnn_cross_validation_results.csv')

# %%
# Evaluate the results

norm_exp_dict = defaultdict(lambda: 'None')
for n, e in zip(exp_norm_map['normal_id'], exp_norm_map['experiment_id']):
    norm_exp_dict[n] = e
results['experiment_sequence'] = results['target_sequence'].map(norm_exp_dict)

metrics = []

# Calculate the metrics for each sequence
for sequence, df in results.groupby('target_sequence'):
    
    completion_target = df['completion_target']
    
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)
    
    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([sequence, 
                    norm_exp_dict[sequence], 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])

# Calculate the metrics for each fold
for fold, df in results.groupby('fold'):
    
    completion_target = df['completion_target']
    completion_prediction = df['completion_prediction']
    completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
    completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
    completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
    completion_mse = mean_squared_error(completion_target, completion_prediction)
    
    problems_target = df[df['completion_target'] == 1]['problems_target']
    problems_prediction = df[df['completion_target'] == 1]['problems_prediction']
    problems_mae = mean_absolute_error(problems_target, problems_prediction)
    problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
    problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
    problems_mse = mean_squared_error(problems_target, problems_prediction)

    metrics.append([f'fold_{fold}', 
                    'None', 
                    len(df), 
                    completion_auc, 
                    completion_acc, 
                    completion_r2, 
                    completion_ev, 
                    completion_mse, 
                    problems_mae, 
                    problems_mape, 
                    problems_r2, 
                    problems_ev, 
                    problems_mse])

# Calculate the metrics for everything combined
completion_target = results['completion_target']
completion_prediction = results['completion_prediction']
completion_auc = roc_auc_score(completion_target, completion_prediction) if len(completion_target.unique()) > 1 else None
completion_acc = accuracy_score(completion_target, completion_prediction > 0.5)
completion_r2 = r2_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
completion_ev = explained_variance_score(completion_target, completion_prediction) if len(completion_target) > 1 else None
completion_mse = mean_squared_error(completion_target, completion_prediction)

problems_target = results[results['completion_target'] == 1]['problems_target']
problems_prediction = results[results['completion_target'] == 1]['problems_prediction']
problems_mae = mean_absolute_error(problems_target, problems_prediction)
problems_mape = mean_absolute_percentage_error(problems_target, problems_prediction)
problems_r2 = r2_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
problems_ev = explained_variance_score(problems_target, problems_prediction) if len(problems_target) > 1 else None
problems_mse = mean_squared_error(problems_target, problems_prediction)

metrics.append(['all_target_data', 
                'None', 
                len(results), 
                completion_auc, 
                completion_acc, 
                completion_r2, 
                completion_ev, 
                completion_mse, 
                problems_mae, 
                problems_mape, 
                problems_r2, 
                problems_ev, 
                problems_mse])

metrics = pd.DataFrame(metrics, 
                       columns=['sequence_id', 
                                'experiment_id', 
                                'sample_size', 
                                'completion_auc', 
                                'completion_acc', 
                                'completion_r2', 
                                'completion_ev', 
                                'completion_mse', 
                                'problems_mae', 
                                'problems_mape', 
                                'problems_r2', 
                                'problems_ev', 
                                'problems_mse'])

metrics.to_csv('cnn_cross_validation_metrics.csv', index=False)

# %%
metrics.iloc[-6:]
# Out:
#          sequence_id experiment_id  sample_size  completion_auc  \
# 288           fold_0          None        42114        0.713366
# 289           fold_1          None        42114        0.716603
# 290           fold_2          None        42114        0.716577
# 291           fold_3          None        42113        0.717868
# 292           fold_4          None        42113        0.712242
# 293  all_target_data          None       210568        0.713960
#
#      completion_acc  completion_r2  completion_ev  completion_mse  \
# 288        0.760650       0.107669       0.109761        0.167063
# 289        0.756494       0.114959       0.115912        0.168484
# 290        0.758869       0.115490       0.116139        0.167756
# 291        0.752238       0.113531       0.114868        0.170270
# 292        0.756299       0.109536       0.110199        0.169385
# 293        0.756910       0.112300       0.112319        0.168592
#
#      problems_mae  problems_mape  problems_r2  problems_ev  problems_mse
# 288      1.814150       0.118643     0.010503     0.026048      7.490417
# 289      1.863959       0.109904    -0.000234     0.019474      9.544704
# 290      1.897481       0.118699     0.000990     0.018566     10.232706
# 291      1.857417       0.136229     0.006839     0.017695      7.831766
# 292      1.866970       0.120647     0.003255     0.020051      8.111379
# 293      1.859935       0.120805     0.004024     0.020033      8.641575
