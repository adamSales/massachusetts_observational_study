# %%
import os
import pandas as pd

# %%
df = pd.read_excel('xlsx/accountability_2012.xlsx', header=[1,2], dtype=str)

# %%
df
# Out:
#                            Unnamed: 0_level_0 Unnamed: 1_level_0  \
#                                   School Name        School Code
# 0                      Abington-Abington High           00010505
# 1     Abington-Beaver Brook Elementary School           00010003
# 2           Abington-Center Elementary School           00010002
# 3               Abington-Frolio Middle School           00010405
# 4        Abington-Woodsdale Elementary School           00010015
# ...                                       ...                ...
# 1823          Worcester-Worcester East Middle           03480420
# 1824       Worcester-Worcester Technical High           03480605
# 1825              Wrentham-Charles E Roderick           03500010
# 1826                         Wrentham-Delaney           03500003
# 1827                                      NaN                NaN
#
#      Unnamed: 2_level_0 Accountability and Assistance Level  \
# ...
