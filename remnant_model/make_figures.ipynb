# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('results/kfold_remnant_predictions.csv', dtype=str)
b = pd.read_csv('input_data/mass_doe_data.csv', dtype=str)[['school_code', 'charter_school']]
a = a.merge(b, how='inner', on='school_code')

# %%
plt.figure()
plt.scatter(a['actual_performance'].astype(float), a['predicted_performance'].astype(float), c=a['charter_school'].astype(float))
plt.xlabel('Actual Performance')
plt.ylabel('Predicted Performance')
plt.title('Yellow = Charter School')
plt.show()

# %%
a['error'] = np.abs(a['predicted_performance'].astype(float) - a['actual_performance'].astype(float))

# %%
a.sort_values('error', ascending=False).head(10)
# Out:
#     school_code  actual_performance predicted_performance charter_school  \
# 123    04430205                0.95    0.2706369161605835              0
# 221    07170015                0.86   0.31837859749794006              0
# 0      00350096   0.855111111111111    0.4289277195930481              0
# 173    04610405                0.73   0.30782800912857056              0
# 30     03480145                0.24    0.6077443957328796              0
# 130    07500008                0.32    0.6629467010498047              0
# 306    04940205  0.7341732283464567     0.394792377948761              1
# 263    03480020                0.62   0.29609957337379456              0
# 424    02090035                0.21    0.5240606069564819              0
# 37     06150050                0.22    0.5124461650848389              0
#
#         error
# 123  0.679363
# 221  0.541621
# 0    0.426183
# 173  0.422172
# 30   0.367744
# 130  0.342947
# 306  0.339381
# 263  0.323900
# 424  0.314061
# 37   0.292446
